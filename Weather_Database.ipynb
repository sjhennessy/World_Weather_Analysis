# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = list(zip(lats, lngs))

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 731

# %%
# Use tuple to show lat/lng combos.
for coordinate in coordinates:
    print (citipy.nearest_city(coordinate[0], coordinate[1]).city_name, citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# kokstad za
# gilgit pk
# busselton au
# taolanaro mg
# bethel us
# bud no
# cape town za
# rikitea pf
# provideniya ru
# hermanus za
# kavieng pg
# punta arenas cl
# mahebourg mu
# lavrentiya ru
# kavieng pg
# avarua ck
# lahad datu my
# albany au
# zaqatala az
# kapaa us
# yellowknife ca
# taolanaro mg
# mount gambier au
# zhangjiakou cn
# qaanaaq gl
# sibolga id
# ushuaia ar
# skjervoy no
# rikitea pf
# hilo us
# ushuaia ar
# rungata ki
# kapaa us
# hithadhoo mv
# palu id
# east london za
# alta floresta br
# benguela ao
# upernavik gl
# amderma ru
# nikolskoye ru
# hermanus za
# taoudenni ml
# vila franca do campo pt
# novo aripuana br
# ushuaia ar
# bengkulu id
# bredasdorp za
# avarua ck
# jinji cn
# nikolskoye ru
# kavieng pg
# hithadhoo mv
# kaitangata nz
# hermanus za
# chokurdakh ru
# cape town za
# bluff nz
# mataura pf
# new norfolk au
# ushuaia ar
# lincoln nz
# mataura pf
# hithadhoo mv
# albany au
# ushuaia ar
# lavrentiya ru
# bambous virieux mu
# talnakh ru
# tamandare br
# albany au
# buala sb
# ponta do sol cv
# bourail nc
# bluff nz
# belushya guba ru
# provideniya ru
# morgan city us
# sao filipe cv
# rikitea pf
# ushuaia ar
# bluff nz
# port elizabeth za
# malinovoye ozero ru
# arraial do cabo br
# tuatapere nz
# ushuaia ar
# puerto ayora ec
# bengkulu id
# attawapiskat ca
# ankazoabo mg
# port elizabeth za
# punta arenas cl
# saint-marc ht
# taolanaro mg
# butaritari ki
# tuktoyaktuk ca
# cape town za
# belushya guba ru
# avarua ck
# belushya guba ru
# pevek ru
# khatanga ru
# winslow us
# chokurdakh ru
# hithadhoo mv
# rikitea pf
# barrow us
# ushuaia ar
# mitsamiouli km
# mount isa au
# khatanga ru
# barentsburg sj
# puerto ayora ec
# abong mbang cm
# ostrovnoy ru
# ixtapa mx
# port moresby pg
# mys shmidta ru
# saint george bm
# scottsburgh za
# baykit ru
# lata sb
# marcona pe
# amderma ru
# bluff nz
# east london za
# asau tv
# butaritari ki
# jamestown sh
# rikitea pf
# taolanaro mg
# bluff nz
# saskylakh ru
# lompoc us
# clyde river ca
# atuona pf
# port alfred za
# bereda so
# leningradskiy ru
# barentsburg sj
# nago jp
# camacha pt
# hobart au
# butaritari ki
# saint-philippe re
# taolanaro mg
# hambantota lk
# mitsamiouli km
# barrow us
# ushuaia ar
# jamestown sh
# verdalsora no
# tsihombe mg
# ushuaia ar
# aksu cn
# ushuaia ar
# saldanha za
# port alfred za
# east london za
# vaini to
# mataura pf
# illoqqortoormiut gl
# rio grande br
# bredasdorp za
# cape town za
# ranong th
# mataura pf
# hilo us
# ribeira grande pt
# busselton au
# busselton au
# conde br
# port elizabeth za
# kalengwa zm
# puerto ayora ec
# trinidad bo
# easton us
# asosa et
# sulangan ph
# nemuro jp
# ushuaia ar
# rikitea pf
# chokurdakh ru
# belushya guba ru
# ushuaia ar
# port lincoln au
# prince rupert ca
# evensk ru
# warrnambool au
# raudeberg no
# atuona pf
# chuy uy
# marystown ca
# verkhoyansk ru
# arambagh in
# vaini to
# provideniya ru
# tautira pf
# bocaranga cf
# mar del plata ar
# albany au
# sarkand kz
# saint anthony ca
# barcelos br
# rikitea pf
# atuona pf
# east london za
# zhigansk ru
# vaini to
# buchanan lr
# padang id
# east london za
# avarua ck
# cape town za
# hermanus za
# la ronge ca
# khatanga ru
# cueramaro mx
# ushuaia ar
# ushuaia ar
# ponta do sol cv
# port alfred za
# taolanaro mg
# sakakah sa
# aklavik ca
# mys shmidta ru
# avarua ck
# marsa matruh eg
# cape town za
# busselton au
# afgoye so
# dunmore town bs
# amderma ru
# upernavik gl
# port-gentil ga
# thompson ca
# ushuaia ar
# coruripe br
# khatanga ru
# chuy uy
# pevek ru
# thompson ca
# impfondo cg
# atuona pf
# hobart au
# hilo us
# haines junction ca
# khatanga ru
# meyungs pw
# cape town za
# mandalgovi mn
# honavar in
# mbigou ga
# victoria sc
# kavieng pg
# rikitea pf
# salalah om
# carnarvon au
# mahebourg mu
# sentyabrskiy ru
# brookings us
# gao ml
# taolanaro mg
# jamestown sh
# amderma ru
# ketchikan us
# punta arenas cl
# jalu ly
# ushuaia ar
# zhigansk ru
# zlobin by
# atuona pf
# tasiilaq gl
# xinqing cn
# nago jp
# talcahuano cl
# north bend us
# castro cl
# port alfred za
# shyryayeve ua
# tuktoyaktuk ca
# erzin ru
# kyren ru
# karauzyak uz
# arraial do cabo br
# pangody ru
# cape town za
# illoqqortoormiut gl
# bressanone it
# jalu ly
# illoqqortoormiut gl
# port-gentil ga
# hermanus za
# avarua ck
# busselton au
# laguna br
# khatanga ru
# rikitea pf
# linjiang cn
# rikitea pf
# rikitea pf
# bury saint edmunds gb
# busselton au
# hermanus za
# nome us
# dongsheng cn
# southbridge nz
# sisimiut gl
# mendeleyevskiy ru
# vila do maio cv
# upernavik gl
# rikitea pf
# lata sb
# mataura pf
# avarua ck
# vratnica mk
# kailua us
# wuwei cn
# ponta do sol cv
# bengkulu id
# attawapiskat ca
# batemans bay au
# baruun-urt mn
# candolim in
# thompson ca
# wad rawah sd
# shenjiamen cn
# rikitea pf
# mar del plata ar
# san patricio mx
# mataura pf
# riyadh sa
# hobart au
# tuatapere nz
# poya nc
# pinerolo it
# kahului us
# tuktoyaktuk ca
# madang pg
# atuona pf
# busselton au
# barrow us
# atuona pf
# kidal ml
# puerto ayora ec
# banda aceh id
# el balyana eg
# bengkulu id
# cape town za
# zhigansk ru
# lorengau pg
# venezuela cu
# punta arenas cl
# nikolskoye ru
# ushuaia ar
# clyde river ca
# laguna br
# mys shmidta ru
# barrow us
# busselton au
# busselton au
# touros br
# new norfolk au
# adigeni ge
# grand gaube mu
# vaini to
# ribeira grande pt
# yeniseysk ru
# pevek ru
# namibe ao
# bati et
# busselton au
# sambava mg
# yellowknife ca
# busselton au
# east london za
# guerrero negro mx
# chochola mx
# grindavik is
# bulawayo zw
# caravelas br
# khatanga ru
# pevek ru
# birjand ir
# mataura pf
# busselton au
# casablanca ma
# tavricheskoye ru
# tubruq ly
# tuktoyaktuk ca
# cape town za
# port alfred za
# meyungs pw
# coquimbo cl
# yirol sd
# tasiilaq gl
# jamestown sh
# dikson ru
# puerto ayora ec
# provideniya ru
# yellowknife ca
# busselton au
# verkhnyaya inta ru
# port alfred za
# inhambane mz
# saldanha za
# tyret pervaya ru
# mataura pf
# puerto ayora ec
# ushuaia ar
# carmen cr
# sorvag fo
# upernavik gl
# vila vu
# vaini to
# albany au
# marcona pe
# tiksi ru
# aklavik ca
# ushuaia ar
# illoqqortoormiut gl
# albany au
# yenagoa ng
# san antonio cl
# sibut cf
# rikitea pf
# avarua ck
# rikitea pf
# hobart au
# ribeira grande pt
# jumla np
# kodiak us
# port alfred za
# callaway us
# khatanga ru
# punta arenas cl
# ushuaia ar
# kiama au
# saint anthony ca
# busselton au
# ponta do sol cv
# castro cl
# sobolevo ru
# hermanus za
# rikitea pf
# namibe ao
# ribeira grande pt
# thanh hoa vn
# hobyo so
# mataura pf
# lat yao th
# ponta do sol cv
# cherskiy ru
# rikitea pf
# makakilo city us
# torbay ca
# mar del plata ar
# cape town za
# cherskiy ru
# ono jp
# busselton au
# road town vg
# atar mr
# acworth us
# kapaa us
# bredasdorp za
# solnechnyy ru
# barrow us
# emporia us
# cidreira br
# rikitea pf
# fayetteville us
# ancud cl
# bluff nz
# narsaq gl
# berlevag no
# ilulissat gl
# coquimbo cl
# ahipara nz
# mataura pf
# mataura pf
# tiksi ru
# sept-iles ca
# punta arenas cl
# vila franca do campo pt
# vihti fi
# taolanaro mg
# clyde river ca
# morehead pg
# jalu ly
# bambous virieux mu
# soure br
# kamenka ru
# manyana bw
# vaini to
# upernavik gl
# nebug ru
# joensuu fi
# attawapiskat ca
# busselton au
# panjab af
# mataura pf
# taolanaro mg
# boyolangu id
# rikitea pf
# atmakur in
# jamestown sh
# cuamba mz
# albany au
# hithadhoo mv
# inongo cd
# yellowknife ca
# mataura pf
# uzhur ru
# port alfred za
# khatanga ru
# port alfred za
# mahebourg mu
# aklavik ca
# aksu kz
# busselton au
# hithadhoo mv
# kondinskoye ru
# nokaneng bw
# yellowknife ca
# saint-philippe re
# amderma ru
# yellowknife ca
# hobart au
# mataura pf
# alta floresta br
# mataura pf
# busselton au
# lazarev ru
# attawapiskat ca
# biak id
# lima pe
# taolanaro mg
# ushuaia ar
# busselton au
# georgetown sh
# kapaa us
# inhambane mz
# karangasem id
# palabuhanratu id
# sungaipenuh id
# norman wells ca
# tulsipur np
# aykhal ru
# panjakent tj
# hobart au
# kahului us
# yulara au
# jamestown sh
# krasnovishersk ru
# acari pe
# longyearbyen sj
# butaritari ki
# barrow us
# ilulissat gl
# lompoc us
# novonukutskiy ru
# katsuura jp
# amderma ru
# asau tv
# aurillac fr
# egvekinot ru
# bluff nz
# chara ru
# rikitea pf
# litovko ru
# sergiyevsk ru
# cape town za
# lyndon us
# mataura pf
# kapaa us
# asfi ma
# ayan ru
# qaanaaq gl
# jamestown sh
# teya ru
# punta arenas cl
# arraial do cabo br
# illoqqortoormiut gl
# berlevag no
# cape town za
# contamana pe
# butaritari ki
# amderma ru
# hilo us
# brae gb
# east london za
# alice springs au
# severnyy ru
# touros br
# castro cl
# sinnamary gf
# tamale gh
# bluff nz
# raudeberg no
# haines junction ca
# bubaque gw
# kutum sd
# luganville vu
# kalayaan ph
# hilo us
# cape town za
# mar del plata ar
# codrington ag
# mataura pf
# ushuaia ar
# mahebourg mu
# ushuaia ar
# autun fr
# mount gambier au
# lerwick gb
# isangel vu
# punta arenas cl
# tsihombe mg
# rikitea pf
# cherskiy ru
# pisco pe
# bathsheba bb
# omsukchan ru
# bredasdorp za
# arinos br
# port alfred za
# hithadhoo mv
# bluff nz
# butaritari ki
# atuona pf
# busselton au
# upernavik gl
# kargasok ru
# rikitea pf
# bluff nz
# tommot ru
# dillon us
# royan fr
# scarborough gb
# rikitea pf
# gigmoto ph
# cape town za
# ponta do sol cv
# bluff nz
# severo-kurilsk ru
# chuy uy
# bredasdorp za
# vaini to
# avarua ck
# mataura pf
# viedma ar
# aleksandrov gay ru
# sorvag fo
# kapaa us
# tsihombe mg
# guerrero negro mx
# klaksvik fo
# rikitea pf
# fortuna us
# rosetown ca
# horsham au
# hithadhoo mv
# albany au
# ushuaia ar
# tungkang tw
# albany au
# albany au
# saldanha za
# bredasdorp za
# tura ru
# arman ru
# broken hill au
# laives it
# provideniya ru
# rikitea pf
# kruisfontein za
# port alfred za
# bluff nz
# comodoro rivadavia ar
# bambous virieux mu
# ciudad ojeda ve
# butaritari ki
# leningradskiy ru
# east london za
# longyearbyen sj
# ardistan ir
# clyde river ca
# cape town za
# limbang my
# kapaa us
# avarua ck
# matagami ca
# khatanga ru
# longyearbyen sj
# east london za
# hermanus za
# amderma ru
# ushuaia ar
# illoqqortoormiut gl
# baiao br
# rawannawi ki
# rikitea pf
# aklavik ca
# tuktoyaktuk ca
# suntar ru
# souillac mu
# cape town za
# muros es
# port moresby pg
# palimbang ph
# ushuaia ar
# golden ca
# albany au
# new norfolk au
# port alfred za
# busselton au
# kropotkin ru
# chernyanka ru
# marcona pe
# esperance au
# callaway us
# mataura pf
# qaanaaq gl
# ushuaia ar
# gabriel leyva solano mx
# yellowknife ca
# sri aman my
# algarrobo co
# atuona pf
# tura ru
# kruisfontein za
# teya ru
# ekibastuz kz
# ancud cl
# rikitea pf
# east london za
# eyl so
# dikson ru
# woodward us
# port blair in
# nikolskoye ru
# kidal ml
# mataura pf
# punta arenas cl
# beja pt
# sept-iles ca
# havelock us
# ribeira grande pt
# padang id
# attawapiskat ca
# ambilobe mg
# cape town za
# laurel us
# khatanga ru
# yellowknife ca
# vaini to
# busselton au
# alta floresta br
# cabo san lucas mx
# yulara au
# chalmette us
# mys shmidta ru
# vanimo pg
# chake chake tz
# punta arenas cl
# tiksi ru
# riverton us
# mercedes ar
# torbay ca
# hilo us
# walvis bay na
# souillac mu
# carnarvon au
# tuggurt dz
# bredasdorp za
# santa maria cv
# avarua ck
# bambous virieux mu
# raga sd
# punta arenas cl
# sabang id
# acari pe
# isla mujeres mx
# severo-kurilsk ru
# esperance au
# provideniya ru
# albany au
# hithadhoo mv
# butaritari ki
# ukiah us
# atuona pf
# amderma ru
# provideniya ru
# victoria sc
# puri in
# kavaratti in
# sakakah sa
# sorvag fo
# ushuaia ar
# busselton au
# luderitz na
# teya ru
# kapaa us
# bluff nz
# champerico gt
# hobart au
# qaanaaq gl
# cape town za
# tiksi ru
# port elizabeth za
# kodiak us
# srednekolymsk ru
# nizhniy ingash ru
# agadir ma
# longyan cn
# yumen cn
# pisco pe
# haines junction ca
# yar-sale ru
# mataura pf
# gulu ug
# hobart au
# ushuaia ar
# taolanaro mg
# killybegs ie
# ushuaia ar
# castro cl
# busselton au
# cabedelo br
# atuona pf
# tuktoyaktuk ca
# solok id
# bluff nz
# birao cf
# rikitea pf
# vaitupu wf
# kiruna se
# ibaiti br
# jardim br
# ushuaia ar
# atuona pf
# meulaboh id
# albany au
# qaanaaq gl
# cidreira br
# korla cn
# luganville vu
# khatanga ru
# kapaa us
# taolanaro mg
# ushuaia ar
# ushuaia ar
# eastlake us
# luderitz na
# jamestown sh
# lithakia gr
# jamestown sh
# lompoc us
# kruisfontein za
# rocha uy
# port alfred za
# los llanos de aridane es
# thompson ca
# sitka us
# lata sb
# tornio fi
# sibiti cg
# tuktoyaktuk ca
# rikitea pf
# hilo us
# alamos mx
# jamestown sh
# sentyabrskiy ru
# bonavista ca
# yellowknife ca
# saint-philippe re
# mys shmidta ru
# puerto ayora ec
# souillac mu
# albany au
# cape town za
# ushuaia ar
# vardo no
# egvekinot ru
# komsomolskiy ru
# bosaso so
# puro ph
# caravelas br
# college us
# bluff nz
# esperance au
# saint george bm
# canguaretama br
# hermanus za
# ilinsko-podomskoye ru
# mataura pf
# inirida co
# ilhabela br
# akcaabat tr
# baijiantan cn
# vaini to
# aksehir tr
# olinda br
# busselton au
# pevek ru
# ribeira grande pt
# kaitangata nz
# eureka us
# narsaq gl
# san policarpo ph
# cape town za
# busselton au
# geraldton au
# san agustin sv
# ushuaia ar
# hithadhoo mv
# qaanaaq gl
# leningradskiy ru
# kasongo-lunda cd
# avarua ck
# henties bay na
# moose factory ca
# meulaboh id
# aklavik ca
# bengkulu id
# provideniya ru
# taolanaro mg
# cape town za
# cape town za
# vaini to
# bengkulu id
# busselton au
# paucartambo pe
# grand river south east mu
# bredasdorp za
# bredasdorp za
# rikitea pf
# vaitupu wf
# castro cl
# wladyslawowo pl
# vaini to
# riachao das neves br
# milkovo ru
# puerto ayora ec
# barrow us
# mahebourg mu
# prokudskoye ru
# new norfolk au
# sobolevo ru
# ushuaia ar
# lebu cl
# bluff nz
# airai pw
# namatanai pg
# vaini to
# chumikan ru
# belushya guba ru
# kapaa us
# avarua ck
# nome us
# upernavik gl
# mareeba au
# jamestown sh
# arraial do cabo br
# punta arenas cl
# naryan-mar ru
# hermanus za
# punta arenas cl
# jamestown sh
# chumikan ru
# qaanaaq gl
# saint-ambroise ca
# butaritari ki
# rikitea pf
# ponta do sol cv
# tahta eg
# mataura pf
# andenes no
# aswan eg
# bluff nz
# hobart au
# bluff nz
# san cristobal ec
# puerto ayora ec
# punta arenas cl
# kapoeta sd
# tsihombe mg
# bhag pk
# hobart au
# narsaq gl
# faanui pf
# kazalinsk kz
# cayenne gf
# severo-kurilsk ru
# tasiilaq gl
# ushuaia ar
# albany au
# viligili mv
# ushuaia ar
# bluff nz
# bolshaya glushitsa ru
# dunedin nz
# chilca pe
# leningradskiy ru
# forrest city us
# yellowknife ca
# illoqqortoormiut gl
# ushuaia ar
# kodiak us
# norman wells ca
# albany au
# filingue ne
# fougamou ga
# hermanus za
# vitimskiy ru
# ambilobe mg
# black river jm
# airai pw
# carnarvon au
# busselton au
# mar del plata ar
# taolanaro mg
# hithadhoo mv
# leningradskiy ru
# barrow us
# kavieng pg
# nioro ml
# yulara au
# acapulco mx
# ushuaia ar
# cape town za
# butaritari ki
# new norfolk au
# taolanaro mg
# busselton au
# koudougou bf
# mataura pf
# barentsburg sj
# bengkulu id
# nizhneyansk ru
# rikitea pf
# eureka us
# yellowknife ca
# puerto ayora ec
# roald no
# faanui pf
# thompson ca
# cape town za
# katsuura jp
# kapaa us
# kumluca tr
# sentyabrskiy ru
# bredasdorp za
# hami cn
# cape town za
# hermanus za
# vaini to
# khilok ru
# cockburn town bs
# coquimbo cl
# jamestown sh
# port alfred za
# san carlos bo
# ushuaia ar
# mys shmidta ru
# bredasdorp za
# gizo sb
# ushuaia ar
# nyamuswa tz
# lander us
# saint-philippe re
# sisimiut gl
# hobart au
# rikitea pf
# busselton au
# esperance au
# rikitea pf
# belushya guba ru
# berlevag no
# cape town za
# atuona pf
# dikson ru
# kodiak us
# karaul ru
# cherskiy ru
# bad bramstedt de
# aripuana br
# saint-philippe re
# lhokseumawe id
# busselton au
# ribeira grande pt
# talcahuano cl
# bengkulu id
# labuhan id
# terra santa br
# albany au
# butaritari ki
# kavieng pg
# tejupilco mx
# tumannyy ru
# punta arenas cl
# guadix es
# mbandaka cd
# aljezur pt
# kodiak us
# rocha uy
# atbasar kz
# castro cl
# tilichiki ru
# saldanha za
# haines junction ca
# pinawa ca
# lebu cl
# makarov ru
# kapaa us
# vardo no
# lolua tv
# airai pw
# yellowknife ca
# cape town za
# belushya guba ru
# jamestown sh
# hilo us
# eyl so
# barrow us
# nova vicosa br
# cape town za
# mar del plata ar
# funadhoo mv
# new norfolk au
# segezha ru
# ushuaia ar
# jamestown sh
# jamestown sh
# faanui pf
# bambous virieux mu
# mys shmidta ru
# kieta pg
# ushuaia ar
# dikson ru
# cidreira br
# avarua ck
# husavik is
# port lincoln au
# faanui pf
# punta arenas cl
# hermanus za
# illoqqortoormiut gl
# vaini to
# hermanus za
# bubaque gw
# castro cl
# cap malheureux mu
# albany au
# ushuaia ar
# yellowknife ca
# esperance au
# albany au
# kahului us
# yomou gn
# puerto ayora ec
# vaini to
# new norfolk au
# kapaa us
# karoi zw
# mar del plata ar
# punta arenas cl
# taolanaro mg
# pafos cy
# aleksandrov gay ru
# cloquet us
# tahoua ne
# arraial do cabo br
# araouane ml
# srednekolymsk ru
# busselton au
# serenje zm
# rikitea pf
# sinnamary gf
# brae gb
# quchan ir
# mataura pf
# nizhneyansk ru
# kodiak us
# lazaro cardenas mx
# mataura pf
# punta arenas cl
# yulara au
# saint george bm
# kloulklubed pw
# ushuaia ar
# trapani it
# kaitangata nz
# linxia cn
# novyy urengoy ru
# rikitea pf
# coahuayana mx
# amderma ru
# mataura pf
# port alfred za
# provideniya ru
# oranjestad an
# barrow us
# mezen ru
# demir kapija mk
# ushuaia ar
# georgetown sh
# illoqqortoormiut gl
# mataura pf
# sitka us
# flinders au
# norman wells ca
# vaini to
# rikitea pf
# hermanus za
# kosh-agach ru
# pacifica us
# port alfred za
# honningsvag no
# rikitea pf
# mataura pf
# rikitea pf
# puerto ayora ec
# bethel us
# atuona pf
# port alfred za
# castro cl
# rikitea pf
# cayenne gf
# kuytun ru
# geraldton au
# ushuaia ar
# constitucion mx
# fort nelson ca
# poum nc
# rikitea pf
# yellowknife ca
# busselton au
# new norfolk au
# vaini to
# marsh harbour bs
# coihaique cl
# dodge city us
# busselton au
# norman wells ca
# miles city us
# srednekolymsk ru
# rikitea pf
# seoul kr
# chalus ir
# leningradskiy ru
# carnarvon au
# charapan mx
# hobart au
# codrington ag
# berdigestyakh ru
# rikitea pf
# avarua ck
# punta arenas cl
# khatanga ru
# puerto ayora ec
# turukhansk ru
# belluru in
# marcona pe
# rikitea pf
# hobart au
# chuy uy
# vaini to
# pacific grove us
# laje br
# sistranda no
# carnarvon au
# yellowknife ca
# naze jp
# hilo us
# marsabit ke
# viedma ar
# mar del plata ar
# bredasdorp za
# barentsburg sj
# dimbokro ci
# rikitea pf
# kapaa us
# quatre cocos mu
# hobart au
# port elizabeth za
# baherden tm
# avarua ck
# taolanaro mg
# knysna za
# piacabucu br
# kayerkan ru
# kavieng pg
# olinda br
# moose factory ca
# padang id
# worthing gb
# nantucket us
# hithadhoo mv
# butaritari ki
# mataura pf
# bluff nz
# loandjili cg
# raudeberg no
# mataura pf
# inhambane mz
# bathsheba bb
# coquimbo cl
# taolanaro mg
# broken hill au
# omsukchan ru
# shache cn
# bagdarin ru
# grootfontein na
# geraldton au
# busselton au
# avarua ck
# bethel us
# sayyan ye
# cape town za
# saint-augustin ca
# avarua ck
# halalo wf
# ushuaia ar
# busselton au
# tabiauea ki
# klaksvik fo
# lolua tv
# okha in
# punta arenas cl
# ushuaia ar
# lakatoro vu
# manacapuru br
# hobart au
# skibbereen ie
# punta arenas cl
# yarada in
# kavieng pg
# hilo us
# mys shmidta ru
# hilo us
# lebu cl
# ferrol es
# lompoc us
# puerto ayora ec
# garowe so
# bluff nz
# geraldton au
# jamestown sh
# mantua cu
# rikitea pf
# hermanus za
# cidreira br
# albany au
# rikitea pf
# chichester gb
# vaini to
# pevek ru
# yellowknife ca
# rikitea pf
# mehamn no
# mar del plata ar
# norman wells ca
# banda aceh id
# rikitea pf
# vaini to
# hithadhoo mv
# namatanai pg
# coihaique cl
# punta arenas cl
# hobart au
# pevek ru
# punta arenas cl
# kisangani cd
# saint-philippe re
# taolanaro mg
# lebu cl
# chabahar ir
# floro no
# nouadhibou mr
# ulety ru
# andra ru
# butaritari ki
# vao nc
# saint-philippe re
# tautira pf
# upernavik gl
# tatawin tn
# biak id
# hithadhoo mv
# bluff nz
# esperance au
# esperance au
# avarua ck
# sobolevo ru
# atuona pf
# kupang id
# ribeira grande pt
# lyngseidet no
# geraldton au
# thompson ca
# pishin pk
# banda aceh id
# thompson ca
# meulaboh id
# gat ly
# busselton au
# provideniya ru
# jamestown sh
# saskylakh ru
# rikitea pf
# guerrero negro mx
# yellowknife ca
# saskylakh ru
# arraial do cabo br
# nelson bay au
# eravur lk
# sitka us
# vaitupu wf
# biak id
# atuona pf
# quchan ir
# atuona pf
# ushuaia ar
# santa margherita ligure it
# tsihombe mg
# alyangula au
# jackson us
# odweyne so
# new norfolk au
# sturgis us
# bredasdorp za
# mahibadhoo mv
# bluff nz
# port lincoln au
# kodiak us
# talnakh ru
# rikitea pf
# bethel us
# rikitea pf
# dikson ru
# sinnar sd
# arlit ne
# arkhangelsk ru
# mataura pf
# punta arenas cl
# bethel us
# kavaratti in
# vao nc
# avarua ck
# qaanaaq gl
# atuona pf
# terra rica br
# rikitea pf
# glendive us
# cape town za
# lagoa pt
# hithadhoo mv
# shitanjing cn
# chake chake tz
# aasiaat gl
# khatanga ru
# vestmannaeyjar is
# port elizabeth za
# nemuro jp
# amderma ru
# smolenka ru
# taolanaro mg
# jamestown sh
# waipawa nz
# pajapan mx
# castro cl
# poum nc
# phan thiet vn
# new norfolk au
# clyde river ca
# castro cl
# taolanaro mg
# qaanaaq gl
# hilo us
# carnarvon au
# port blair in
# ibague co
# butaritari ki
# hobart au
# ushuaia ar
# haines junction ca
# hamilton us
# port alfred za
# victoria sc
# sorvag fo
# victoria sc
# praia da vitoria pt
# ajdabiya ly
# bubaque gw
# rikitea pf
# amderma ru
# yumen cn
# airai pw
# busselton au
# warqla dz
# antalaha mg
# busselton au
# punta arenas cl
# saint george bm
# hithadhoo mv
# ekibastuz kz
# ribeira grande pt
# georgetown sh
# port elizabeth za
# saint anthony ca
# doctor pedro p. pena py
# bluff nz
# thompson ca
# san quintin mx
# yatou cn
# bluff nz
# busselton au
# lompoc us
# thung song th
# puerto ayora ec
# mataura pf
# tautira pf
# bergama tr
# cape town za
# albany au
# busselton au
# mount pleasant us
# rikitea pf
# amderma ru
# taolanaro mg
# jamestown sh
# la plata ar
# carutapera br
# cap malheureux mu
# punta arenas cl
# castro cl
# avarua ck
# bonfim br
# belushya guba ru
# hami cn
# mahebourg mu
# zwedru lr
# hilo us
# ushuaia ar
# ribeira grande pt
# pevek ru
# upernavik gl
# kavieng pg
# vaini to
# mnogovershinnyy ru
# orsk ru
# whitehorse ca
# carnarvon au
# rafaela ar
# souillac mu
# lahad datu my
# georgetown sh
# busselton au
# klaksvik fo
# kon tum vn
# fortuna us
# howard springs au
# boueni yt
# beitbridge zw
# saurimo ao
# nyurba ru
# nome us
# sarangani ph
# grand gaube mu
# nadym ru
# saskylakh ru
# yellowknife ca
# mataura pf
# tefe br
# vicuna cl
# joshimath in
# usinsk ru
# hermanus za
# vostok ru
# mahebourg mu
# walla walla us
# baghdad iq
# aljezur pt
# avarua ck
# saint-philippe re
# bethel us
# obo cf
# rikitea pf
# rikitea pf
# veraval in
# rikitea pf
# qaanaaq gl
# lagoa pt
# visnes no
# bengkulu id
# albany au
# barentsburg sj
# ossora ru
# meulaboh id
# albany au
# yellowknife ca
# east london za
# augustow pl
# nouadhibou mr
# luderitz na
# palmer us
# punta arenas cl
# upernavik gl
# vila velha br
# ushuaia ar
# ponta do sol cv
# albany au
# atuona pf
# ponta do sol cv
# longyearbyen sj
# allanmyo mm
# east london za
# morgan city us
# torbay ca
# mana gf
# ushuaia ar
# jamestown sh
# kaohsiung tw
# mataura pf
# mataram id
# albany au
# punta arenas cl
# amderma ru
# jamestown sh
# vardo no
# taolanaro mg
# bontang id
# bilibino ru
# dauriya ru
# emba kz
# altoona us
# carnarvon au
# belushya guba ru
# airai pw
# ushuaia ar
# lavrentiya ru
# mataura pf
# invermere ca
# ola ru
# illoqqortoormiut gl
# butaritari ki
# bathsheba bb
# aban ru
# iqaluit ca
# yar-sale ru
# longyearbyen sj
# tasiilaq gl
# vaini to
# cidreira br
# port blair in
# busselton au
# benguela ao
# barrow us
# dingle ie
# ilulissat gl
# kisangani cd
# mataura pf
# belushya guba ru
# castro cl
# tuggurt dz
# mataura pf
# east london za
# ginir et
# severo-kurilsk ru
# chapais ca
# yinchuan cn
# rio gallegos ar
# georgetown sh
# talnakh ru
# cabo san lucas mx
# vaini to
# hilo us
# busselton au
# rikitea pf
# sinkat sd
# fairbanks us
# barrow us
# punta arenas cl
# faanui pf
# busselton au
# sakakah sa
# new norfolk au
# hamilton bm
# busselton au
# illoqqortoormiut gl
# guerrero negro mx
# kapit my
# lebu cl
# mar del plata ar
# attawapiskat ca
# pinerolo it
# bluff nz
# yenagoa ng
# albany au
# barrow us
# hilo us
# hermanus za
# albany au
# east london za
# hobbs us
# thompson ca
# saskylakh ru
# charters towers au
# butaritari ki
# lakatoro vu
# taolanaro mg
# klaksvik fo
# vitim ru
# itarema br
# kavieng pg
# talnakh ru
# hilo us
# joshimath in
# ushuaia ar
# leningradskiy ru
# belushya guba ru
# khani ru
# mataura pf
# atuona pf
# ambur in
# sena madureira br
# caxito ao
# yellowknife ca
# morondava mg
# the valley ai
# sinnamary gf
# ushuaia ar
# rikitea pf
# laguna br
# mahebourg mu
# grande-riviere ca
# fortuna us
# bredasdorp za
# champerico gt
# barrow us
# hilo us
# kamenskoye ru
# yellowknife ca
# lolua tv
# ushuaia ar
# aklavik ca
# rikitea pf
# augusto correa br
# tasiilaq gl
# mahenge tz
# punta arenas cl
# faanui pf
# nome us
# thompson ca
# coquimbo cl
# merauke id
# bathsheba bb
# busselton au
# avarua ck
# ushuaia ar
# sentyabrskiy ru
# bathsheba bb
# ronne dk
# rikitea pf
# taolanaro mg
# saint-philippe re
# georgetown sh
# barstow us
# tongchuan cn
# san andres co
# mrirt ma
# cape town za
# kapaa us
# jamestown sh
# bluff nz
# upernavik gl
# mataura pf
# vaini to
# zhezkazgan kz
# punta arenas cl
# pozoblanco es
# butaritari ki
# palabuhanratu id
# tezu in
# rikitea pf
# puerto ayora ec
# nguiu au
# mataura pf
# rikitea pf
# codrington ag
# kruisfontein za
# jamestown sh
# puerto quijarro bo
# zhuhai cn
# pimentel pe
# avarua ck
# ushuaia ar
# nikolskoye ru
# barentsburg sj
# hobart au
# vostok ru
# port elizabeth za
# mataura pf
# fare pf
# mataura pf
# gat ly
# bathsheba bb
# mount gambier au
# pitelino ru
# hobart au
# albany au
# labuhan id
# mataura pf
# rikitea pf
# souillac mu
# saldanha za
# ancud cl
# mataura pf
# geraldton au
# coquimbo cl
# kloulklubed pw
# lishui cn
# puerto ayora ec
# sao joao da barra br
# krasnoturansk ru
# punta arenas cl
# hermanus za
# mataura pf
# nuevitas cu
# arraial do cabo br
# tuktoyaktuk ca
# fort morgan us
# punta arenas cl
# avarua ck
# salinopolis br
# sebrovo ru
# fort nelson ca
# rikitea pf
# kaohsiung tw
# atchison us
# hilo us
# hobyo so
# kapaa us
# georgetown sh
# sentyabrskiy ru
# port alfred za
# aklavik ca
# bluff nz
# rikitea pf
# togur ru
# touros br
# khatanga ru
# ulaangom mn
# leshukonskoye ru
# busselton au
# ushuaia ar
# port elizabeth za
# brae gb
# kaitangata nz
# bethel us
# kapaa us
# pergamino ar
# punta arenas cl
# kamenka ru
# punta arenas cl
# hithadhoo mv
# juneau us
# ternate id
# coihaique cl
# pevek ru
# kapaa us
# sao filipe cv
# husavik is
# atambua id
# atuona pf
# albany au
# cidreira br
# olafsvik is
# cape town za
# busselton au
# labuhan id
# gat ly
# vaini to
# oktyabrskoye ru
# nampula mz
# pisco pe
# hithadhoo mv
# tasiilaq gl
# barrow us
# chokurdakh ru
# itarema br
# butaritari ki
# vaini to
# churapcha ru
# norman wells ca
# east london za
# bluff nz
# tacoronte es
# busselton au
# high level ca
# hobart au
# punta arenas cl
# whangamata nz
# kapaa us
# nikolskoye ru
# lebu cl
# nuuk gl
# alexandria eg
# port alfred za
# ushuaia ar
# luderitz na
# kahului us
# new norfolk au
# bluff nz
# thompson ca
# awjilah ly
# lagoa pt
# isangel vu
# alice springs au
# naze jp
# ribeira grande pt
# yarada in
# upernavik gl
# bluff nz
# khatanga ru
# illoqqortoormiut gl
# petropavlovsk-kamchatskiy ru
# souillac mu
# mys shmidta ru
# ushuaia ar
# kahului us
# port elizabeth za
# grand centre ca
# port alfred za
# palmer us
# pangoa pe
# anloga gh
# szekesfehervar hu
# brae gb
# kropotkin ru
# tuktoyaktuk ca
# amderma ru
# isangel vu
# inhambane mz
# high rock bs
# kalmunai lk
# saleaula ws
# mar del plata ar
# hobart au
# aragats am
# okato nz
# puerto escondido mx
# tadine nc
# bengkulu id
# saint-joseph re
# provideniya ru
# bredasdorp za
# barentsburg sj
# ribeira grande pt
# atuona pf
# severo-kurilsk ru
# lebu cl
# ushuaia ar
# westport ie
# dikson ru
# codrington ag
# sagua la grande cu
# hofn is
# hofn is
# nylstroom za
# manggar id
# mataura pf
# algiers dz
# port elizabeth za
# tosno ru
# torbay ca
# dingle ie
# aranos na
# talnakh ru
# mar del plata ar
# ilulissat gl
# smoky lake ca
# maniitsoq gl
# akita jp
# raudeberg no
# gambela et
# agirish ru
# kubachi ru
# rikitea pf
# alugan ph
# dali cn
# portree gb
# harwich us
# pevek ru
# rikitea pf
# laureles py
# tilichiki ru

# %%
# Create an empty list to hold the weather data.
city_data = []

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

# Group cities in sets of 50 for logging purposes.
        if (i % 50 == 0 and i >= 50):
            set_count += 1
            record_count = 1
# Create endpoint URL with each city.
        city_url = url + "&q=" + city.replace(" ","+")

# Log the URL, record, and set numbers and the city.
        print(f"Processing Record {record_count} of Set {set_count} | {city}")
# Add 1 to the record count.
        record_count += 1
    
# Run an API request for each of the cities.
        try:
            # Parse the JSON and retrieve data.
            city_weather = requests.get(city_url).json()
    
            # Parse out the needed data.
            city_country = city_weather["sys"]["country"]
            city_lat = city_weather["coord"]["lat"]
            city_lng = city_weather["coord"]["lon"]
            city_max_temp = city_weather["main"]["temp_max"]
            city_humidity = city_weather["main"]["humidity"]
            city_clouds = city_weather["clouds"]["all"]
            city_wind = city_weather["wind"]["speed"]
            
            
            # Append the city information into city_data list.
            city_data.append({"City": city.title(),
                          "Country": city_country,   
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind})
                        
# If an error is experienced, skip the city.
        except:
            print("City not found. Skipping...")
            pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | kokstad
# Processing Record 2 of Set 1 | gilgit
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | bethel
# Processing Record 6 of Set 1 | bud
# Processing Record 7 of Set 1 | cape town
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | provideniya
# Processing Record 10 of Set 1 | hermanus
# Processing Record 11 of Set 1 | kavieng
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | mahebourg
# Processing Record 14 of Set 1 | lavrentiya
# Processing Record 15 of Set 1 | avarua
# Processing Record 16 of Set 1 | lahad datu
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | zaqatala
# Processing Record 19 of Set 1 | kapaa
# Processing Record 20 of Set 1 | yellowknife
# Processing Record 21 of Set 1 | mount gambier
# Processing Record 22 of Set 1 | zhangjiakou
# Processing Record 23 of Set 1 | qaanaaq
# Processing Record 24 of Set 1 | sibolga
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | skjervoy
# Processing Record 27 of Set 1 | hilo
# Processing Record 28 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 29 of Set 1 | hithadhoo
# Processing Record 30 of Set 1 | palu
# Processing Record 31 of Set 1 | east london
# Processing Record 32 of Set 1 | alta floresta
# Processing Record 33 of Set 1 | benguela
# Processing Record 34 of Set 1 | upernavik
# Processing Record 35 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 1 | nikolskoye
# Processing Record 37 of Set 1 | taoudenni
# Processing Record 38 of Set 1 | vila franca do campo
# Processing Record 39 of Set 1 | novo aripuana
# Processing Record 40 of Set 1 | bengkulu
# Processing Record 41 of Set 1 | bredasdorp
# Processing Record 42 of Set 1 | jinji
# Processing Record 43 of Set 1 | kaitangata
# Processing Record 44 of Set 1 | chokurdakh
# Processing Record 45 of Set 1 | bluff
# Processing Record 46 of Set 1 | mataura
# Processing Record 47 of Set 1 | new norfolk
# Processing Record 48 of Set 1 | lincoln
# Processing Record 49 of Set 1 | bambous virieux
# Processing Record 50 of Set 1 | talnakh
# Processing Record 1 of Set 2 | tamandare
# Processing Record 2 of Set 2 | buala
# Processing Record 3 of Set 2 | ponta do sol
# Processing Record 4 of Set 2 | bourail
# Processing Record 5 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 2 | morgan city
# Processing Record 7 of Set 2 | sao filipe
# Processing Record 8 of Set 2 | port elizabeth
# Processing Record 9 of Set 2 | malinovoye ozero
# Processing Record 10 of Set 2 | arraial do cabo
# Processing Record 11 of Set 2 | tuatapere
# Processing Record 12 of Set 2 | puerto ayora
# Processing Record 13 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 2 | ankazoabo
# Processing Record 15 of Set 2 | saint-marc
# Processing Record 16 of Set 2 | butaritari
# Processing Record 17 of Set 2 | tuktoyaktuk
# Processing Record 18 of Set 2 | pevek
# Processing Record 19 of Set 2 | khatanga
# Processing Record 20 of Set 2 | winslow
# Processing Record 21 of Set 2 | barrow
# Processing Record 22 of Set 2 | mitsamiouli
# Processing Record 23 of Set 2 | mount isa
# Processing Record 24 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 2 | abong mbang
# Processing Record 26 of Set 2 | ostrovnoy
# Processing Record 27 of Set 2 | ixtapa
# Processing Record 28 of Set 2 | port moresby
# Processing Record 29 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 2 | saint george
# Processing Record 31 of Set 2 | scottsburgh
# City not found. Skipping...
# Processing Record 32 of Set 2 | baykit
# Processing Record 33 of Set 2 | lata
# Processing Record 34 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 2 | asau
# Processing Record 36 of Set 2 | jamestown
# Processing Record 37 of Set 2 | saskylakh
# Processing Record 38 of Set 2 | lompoc
# Processing Record 39 of Set 2 | clyde river
# Processing Record 40 of Set 2 | atuona
# Processing Record 41 of Set 2 | port alfred
# Processing Record 42 of Set 2 | bereda
# Processing Record 43 of Set 2 | leningradskiy
# Processing Record 44 of Set 2 | nago
# Processing Record 45 of Set 2 | camacha
# Processing Record 46 of Set 2 | hobart
# Processing Record 47 of Set 2 | saint-philippe
# Processing Record 48 of Set 2 | hambantota
# Processing Record 49 of Set 2 | verdalsora
# City not found. Skipping...
# Processing Record 50 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 3 | aksu
# Processing Record 2 of Set 3 | saldanha
# Processing Record 3 of Set 3 | vaini
# Processing Record 4 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 3 | rio grande
# Processing Record 6 of Set 3 | ranong
# Processing Record 7 of Set 3 | ribeira grande
# Processing Record 8 of Set 3 | conde
# Processing Record 9 of Set 3 | kalengwa
# Processing Record 10 of Set 3 | trinidad
# Processing Record 11 of Set 3 | easton
# Processing Record 12 of Set 3 | asosa
# Processing Record 13 of Set 3 | sulangan
# Processing Record 14 of Set 3 | nemuro
# Processing Record 15 of Set 3 | port lincoln
# Processing Record 16 of Set 3 | prince rupert
# Processing Record 17 of Set 3 | evensk
# Processing Record 18 of Set 3 | warrnambool
# Processing Record 19 of Set 3 | raudeberg
# Processing Record 20 of Set 3 | chuy
# Processing Record 21 of Set 3 | marystown
# Processing Record 22 of Set 3 | verkhoyansk
# Processing Record 23 of Set 3 | arambagh
# Processing Record 24 of Set 3 | tautira
# Processing Record 25 of Set 3 | bocaranga
# City not found. Skipping...
# Processing Record 26 of Set 3 | mar del plata
# Processing Record 27 of Set 3 | sarkand
# Processing Record 28 of Set 3 | saint anthony
# Processing Record 29 of Set 3 | barcelos
# Processing Record 30 of Set 3 | zhigansk
# Processing Record 31 of Set 3 | buchanan
# Processing Record 32 of Set 3 | padang
# Processing Record 33 of Set 3 | la ronge
# Processing Record 34 of Set 3 | cueramaro
# Processing Record 35 of Set 3 | sakakah
# Processing Record 36 of Set 3 | aklavik
# Processing Record 37 of Set 3 | marsa matruh
# Processing Record 38 of Set 3 | afgoye
# City not found. Skipping...
# Processing Record 39 of Set 3 | dunmore town
# Processing Record 40 of Set 3 | port-gentil
# Processing Record 41 of Set 3 | thompson
# Processing Record 42 of Set 3 | coruripe
# Processing Record 43 of Set 3 | impfondo
# Processing Record 44 of Set 3 | haines junction
# Processing Record 45 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 46 of Set 3 | mandalgovi
# Processing Record 47 of Set 3 | honavar
# Processing Record 48 of Set 3 | mbigou
# Processing Record 49 of Set 3 | victoria
# Processing Record 50 of Set 3 | salalah
# Processing Record 1 of Set 4 | carnarvon
# Processing Record 2 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 4 | brookings
# Processing Record 4 of Set 4 | gao
# Processing Record 5 of Set 4 | ketchikan
# Processing Record 6 of Set 4 | jalu
# Processing Record 7 of Set 4 | zlobin
# Processing Record 8 of Set 4 | tasiilaq
# Processing Record 9 of Set 4 | xinqing
# Processing Record 10 of Set 4 | talcahuano
# Processing Record 11 of Set 4 | north bend
# Processing Record 12 of Set 4 | castro
# Processing Record 13 of Set 4 | shyryayeve
# Processing Record 14 of Set 4 | erzin
# Processing Record 15 of Set 4 | kyren
# Processing Record 16 of Set 4 | karauzyak
# City not found. Skipping...
# Processing Record 17 of Set 4 | pangody
# Processing Record 18 of Set 4 | bressanone
# Processing Record 19 of Set 4 | laguna
# Processing Record 20 of Set 4 | linjiang
# Processing Record 21 of Set 4 | bury saint edmunds
# City not found. Skipping...
# Processing Record 22 of Set 4 | nome
# Processing Record 23 of Set 4 | dongsheng
# Processing Record 24 of Set 4 | southbridge
# Processing Record 25 of Set 4 | sisimiut
# Processing Record 26 of Set 4 | mendeleyevskiy
# Processing Record 27 of Set 4 | vila do maio
# Processing Record 28 of Set 4 | vratnica
# Processing Record 29 of Set 4 | kailua
# Processing Record 30 of Set 4 | wuwei
# Processing Record 31 of Set 4 | batemans bay
# Processing Record 32 of Set 4 | baruun-urt
# Processing Record 33 of Set 4 | candolim
# Processing Record 34 of Set 4 | wad rawah
# Processing Record 35 of Set 4 | shenjiamen
# Processing Record 36 of Set 4 | san patricio
# Processing Record 37 of Set 4 | riyadh
# Processing Record 38 of Set 4 | poya
# Processing Record 39 of Set 4 | pinerolo
# Processing Record 40 of Set 4 | kahului
# Processing Record 41 of Set 4 | madang
# Processing Record 42 of Set 4 | kidal
# Processing Record 43 of Set 4 | banda aceh
# Processing Record 44 of Set 4 | el balyana
# City not found. Skipping...
# Processing Record 45 of Set 4 | lorengau
# Processing Record 46 of Set 4 | venezuela
# Processing Record 47 of Set 4 | touros
# Processing Record 48 of Set 4 | adigeni
# Processing Record 49 of Set 4 | grand gaube
# Processing Record 50 of Set 4 | yeniseysk
# Processing Record 1 of Set 5 | namibe
# Processing Record 2 of Set 5 | bati
# Processing Record 3 of Set 5 | sambava
# Processing Record 4 of Set 5 | guerrero negro
# Processing Record 5 of Set 5 | chochola
# Processing Record 6 of Set 5 | grindavik
# Processing Record 7 of Set 5 | bulawayo
# Processing Record 8 of Set 5 | caravelas
# Processing Record 9 of Set 5 | birjand
# Processing Record 10 of Set 5 | casablanca
# Processing Record 11 of Set 5 | tavricheskoye
# Processing Record 12 of Set 5 | tubruq
# City not found. Skipping...
# Processing Record 13 of Set 5 | coquimbo
# Processing Record 14 of Set 5 | yirol
# City not found. Skipping...
# Processing Record 15 of Set 5 | dikson
# Processing Record 16 of Set 5 | verkhnyaya inta
# Processing Record 17 of Set 5 | inhambane
# Processing Record 18 of Set 5 | tyret pervaya
# Processing Record 19 of Set 5 | carmen
# Processing Record 20 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 21 of Set 5 | vila
# Processing Record 22 of Set 5 | tiksi
# Processing Record 23 of Set 5 | yenagoa
# Processing Record 24 of Set 5 | san antonio
# Processing Record 25 of Set 5 | sibut
# Processing Record 26 of Set 5 | jumla
# Processing Record 27 of Set 5 | kodiak
# Processing Record 28 of Set 5 | callaway
# Processing Record 29 of Set 5 | kiama
# Processing Record 30 of Set 5 | sobolevo
# Processing Record 31 of Set 5 | thanh hoa
# Processing Record 32 of Set 5 | hobyo
# Processing Record 33 of Set 5 | lat yao
# Processing Record 34 of Set 5 | cherskiy
# Processing Record 35 of Set 5 | makakilo city
# Processing Record 36 of Set 5 | torbay
# Processing Record 37 of Set 5 | ono
# Processing Record 38 of Set 5 | road town
# Processing Record 39 of Set 5 | atar
# Processing Record 40 of Set 5 | acworth
# Processing Record 41 of Set 5 | solnechnyy
# Processing Record 42 of Set 5 | emporia
# Processing Record 43 of Set 5 | cidreira
# Processing Record 44 of Set 5 | fayetteville
# Processing Record 45 of Set 5 | ancud
# Processing Record 46 of Set 5 | narsaq
# Processing Record 47 of Set 5 | berlevag
# Processing Record 48 of Set 5 | ilulissat
# Processing Record 49 of Set 5 | ahipara
# Processing Record 50 of Set 5 | sept-iles
# Processing Record 1 of Set 6 | vihti
# Processing Record 2 of Set 6 | morehead
# Processing Record 3 of Set 6 | soure
# Processing Record 4 of Set 6 | kamenka
# Processing Record 5 of Set 6 | manyana
# Processing Record 6 of Set 6 | nebug
# Processing Record 7 of Set 6 | joensuu
# Processing Record 8 of Set 6 | panjab
# Processing Record 9 of Set 6 | boyolangu
# Processing Record 10 of Set 6 | atmakur
# Processing Record 11 of Set 6 | cuamba
# Processing Record 12 of Set 6 | inongo
# Processing Record 13 of Set 6 | uzhur
# Processing Record 14 of Set 6 | kondinskoye
# Processing Record 15 of Set 6 | nokaneng
# Processing Record 16 of Set 6 | lazarev
# Processing Record 17 of Set 6 | biak
# Processing Record 18 of Set 6 | lima
# Processing Record 19 of Set 6 | georgetown
# Processing Record 20 of Set 6 | karangasem
# Processing Record 21 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 6 | sungaipenuh
# Processing Record 23 of Set 6 | norman wells
# Processing Record 24 of Set 6 | tulsipur
# Processing Record 25 of Set 6 | aykhal
# Processing Record 26 of Set 6 | panjakent
# Processing Record 27 of Set 6 | yulara
# Processing Record 28 of Set 6 | krasnovishersk
# Processing Record 29 of Set 6 | acari
# Processing Record 30 of Set 6 | longyearbyen
# Processing Record 31 of Set 6 | novonukutskiy
# Processing Record 32 of Set 6 | katsuura
# Processing Record 33 of Set 6 | aurillac
# Processing Record 34 of Set 6 | egvekinot
# Processing Record 35 of Set 6 | chara
# Processing Record 36 of Set 6 | litovko
# Processing Record 37 of Set 6 | sergiyevsk
# Processing Record 38 of Set 6 | lyndon
# Processing Record 39 of Set 6 | asfi
# Processing Record 40 of Set 6 | ayan
# Processing Record 41 of Set 6 | teya
# Processing Record 42 of Set 6 | contamana
# Processing Record 43 of Set 6 | brae
# Processing Record 44 of Set 6 | alice springs
# Processing Record 45 of Set 6 | severnyy
# Processing Record 46 of Set 6 | sinnamary
# Processing Record 47 of Set 6 | tamale
# Processing Record 48 of Set 6 | bubaque
# Processing Record 49 of Set 6 | kutum
# Processing Record 50 of Set 6 | luganville
# Processing Record 1 of Set 7 | kalayaan
# Processing Record 2 of Set 7 | codrington
# Processing Record 3 of Set 7 | autun
# Processing Record 4 of Set 7 | lerwick
# Processing Record 5 of Set 7 | isangel
# Processing Record 6 of Set 7 | pisco
# Processing Record 7 of Set 7 | bathsheba
# Processing Record 8 of Set 7 | omsukchan
# Processing Record 9 of Set 7 | arinos
# Processing Record 10 of Set 7 | kargasok
# Processing Record 11 of Set 7 | tommot
# Processing Record 12 of Set 7 | dillon
# Processing Record 13 of Set 7 | royan
# Processing Record 14 of Set 7 | scarborough
# Processing Record 15 of Set 7 | gigmoto
# Processing Record 16 of Set 7 | severo-kurilsk
# Processing Record 17 of Set 7 | viedma
# Processing Record 18 of Set 7 | aleksandrov gay
# Processing Record 19 of Set 7 | klaksvik
# Processing Record 20 of Set 7 | fortuna
# Processing Record 21 of Set 7 | rosetown
# Processing Record 22 of Set 7 | horsham
# Processing Record 23 of Set 7 | tungkang
# City not found. Skipping...
# Processing Record 24 of Set 7 | tura
# Processing Record 25 of Set 7 | arman
# Processing Record 26 of Set 7 | broken hill
# Processing Record 27 of Set 7 | laives
# Processing Record 28 of Set 7 | kruisfontein
# Processing Record 29 of Set 7 | comodoro rivadavia
# Processing Record 30 of Set 7 | ciudad ojeda
# Processing Record 31 of Set 7 | ardistan
# City not found. Skipping...
# Processing Record 32 of Set 7 | limbang
# Processing Record 33 of Set 7 | matagami
# Processing Record 34 of Set 7 | baiao
# Processing Record 35 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 36 of Set 7 | suntar
# Processing Record 37 of Set 7 | souillac
# Processing Record 38 of Set 7 | muros
# Processing Record 39 of Set 7 | palimbang
# Processing Record 40 of Set 7 | golden
# Processing Record 41 of Set 7 | kropotkin
# Processing Record 42 of Set 7 | chernyanka
# Processing Record 43 of Set 7 | esperance
# Processing Record 44 of Set 7 | gabriel leyva solano
# Processing Record 45 of Set 7 | sri aman
# Processing Record 46 of Set 7 | algarrobo
# Processing Record 47 of Set 7 | ekibastuz
# Processing Record 48 of Set 7 | eyl
# Processing Record 49 of Set 7 | woodward
# Processing Record 50 of Set 7 | port blair
# Processing Record 1 of Set 8 | beja
# Processing Record 2 of Set 8 | havelock
# Processing Record 3 of Set 8 | ambilobe
# Processing Record 4 of Set 8 | laurel
# Processing Record 5 of Set 8 | cabo san lucas
# Processing Record 6 of Set 8 | chalmette
# Processing Record 7 of Set 8 | vanimo
# Processing Record 8 of Set 8 | chake chake
# Processing Record 9 of Set 8 | riverton
# Processing Record 10 of Set 8 | mercedes
# Processing Record 11 of Set 8 | walvis bay
# Processing Record 12 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 13 of Set 8 | santa maria
# Processing Record 14 of Set 8 | raga
# Processing Record 15 of Set 8 | sabang
# Processing Record 16 of Set 8 | isla mujeres
# Processing Record 17 of Set 8 | ukiah
# Processing Record 18 of Set 8 | puri
# Processing Record 19 of Set 8 | kavaratti
# Processing Record 20 of Set 8 | luderitz
# Processing Record 21 of Set 8 | champerico
# Processing Record 22 of Set 8 | srednekolymsk
# Processing Record 23 of Set 8 | nizhniy ingash
# Processing Record 24 of Set 8 | agadir
# Processing Record 25 of Set 8 | longyan
# Processing Record 26 of Set 8 | yumen
# Processing Record 27 of Set 8 | yar-sale
# Processing Record 28 of Set 8 | gulu
# Processing Record 29 of Set 8 | killybegs
# Processing Record 30 of Set 8 | cabedelo
# Processing Record 31 of Set 8 | solok
# Processing Record 32 of Set 8 | birao
# Processing Record 33 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 8 | kiruna
# Processing Record 35 of Set 8 | ibaiti
# Processing Record 36 of Set 8 | jardim
# Processing Record 37 of Set 8 | meulaboh
# Processing Record 38 of Set 8 | korla
# Processing Record 39 of Set 8 | eastlake
# Processing Record 40 of Set 8 | lithakia
# Processing Record 41 of Set 8 | rocha
# Processing Record 42 of Set 8 | los llanos de aridane
# Processing Record 43 of Set 8 | sitka
# Processing Record 44 of Set 8 | tornio
# Processing Record 45 of Set 8 | sibiti
# Processing Record 46 of Set 8 | alamos
# Processing Record 47 of Set 8 | bonavista
# Processing Record 48 of Set 8 | vardo
# Processing Record 49 of Set 8 | komsomolskiy
# Processing Record 50 of Set 8 | bosaso
# Processing Record 1 of Set 9 | puro
# Processing Record 2 of Set 9 | college
# Processing Record 3 of Set 9 | canguaretama
# Processing Record 4 of Set 9 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 5 of Set 9 | inirida
# Processing Record 6 of Set 9 | ilhabela
# Processing Record 7 of Set 9 | akcaabat
# Processing Record 8 of Set 9 | baijiantan
# Processing Record 9 of Set 9 | aksehir
# Processing Record 10 of Set 9 | olinda
# Processing Record 11 of Set 9 | eureka
# Processing Record 12 of Set 9 | san policarpo
# Processing Record 13 of Set 9 | geraldton
# Processing Record 14 of Set 9 | san agustin
# Processing Record 15 of Set 9 | kasongo-lunda
# Processing Record 16 of Set 9 | henties bay
# Processing Record 17 of Set 9 | moose factory
# Processing Record 18 of Set 9 | paucartambo
# City not found. Skipping...
# Processing Record 19 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 9 | wladyslawowo
# Processing Record 21 of Set 9 | riachao das neves
# Processing Record 22 of Set 9 | milkovo
# Processing Record 23 of Set 9 | prokudskoye
# Processing Record 24 of Set 9 | lebu
# Processing Record 25 of Set 9 | airai
# Processing Record 26 of Set 9 | namatanai
# Processing Record 27 of Set 9 | chumikan
# Processing Record 28 of Set 9 | mareeba
# Processing Record 29 of Set 9 | naryan-mar
# Processing Record 30 of Set 9 | saint-ambroise
# Processing Record 31 of Set 9 | tahta
# Processing Record 32 of Set 9 | andenes
# Processing Record 33 of Set 9 | aswan
# Processing Record 34 of Set 9 | san cristobal
# Processing Record 35 of Set 9 | kapoeta
# Processing Record 36 of Set 9 | bhag
# Processing Record 37 of Set 9 | faanui
# Processing Record 38 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 39 of Set 9 | cayenne
# Processing Record 40 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 41 of Set 9 | bolshaya glushitsa
# Processing Record 42 of Set 9 | dunedin
# Processing Record 43 of Set 9 | chilca
# Processing Record 44 of Set 9 | forrest city
# Processing Record 45 of Set 9 | filingue
# Processing Record 46 of Set 9 | fougamou
# Processing Record 47 of Set 9 | vitimskiy
# City not found. Skipping...
# Processing Record 48 of Set 9 | black river
# Processing Record 49 of Set 9 | nioro
# Processing Record 50 of Set 9 | acapulco
# Processing Record 1 of Set 10 | koudougou
# Processing Record 2 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 10 | roald
# Processing Record 4 of Set 10 | kumluca
# Processing Record 5 of Set 10 | hami
# Processing Record 6 of Set 10 | khilok
# Processing Record 7 of Set 10 | cockburn town
# Processing Record 8 of Set 10 | san carlos
# Processing Record 9 of Set 10 | gizo
# Processing Record 10 of Set 10 | nyamuswa
# Processing Record 11 of Set 10 | lander
# Processing Record 12 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 13 of Set 10 | bad bramstedt
# Processing Record 14 of Set 10 | aripuana
# Processing Record 15 of Set 10 | lhokseumawe
# Processing Record 16 of Set 10 | labuhan
# Processing Record 17 of Set 10 | terra santa
# Processing Record 18 of Set 10 | tejupilco
# City not found. Skipping...
# Processing Record 19 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 10 | guadix
# Processing Record 21 of Set 10 | mbandaka
# Processing Record 22 of Set 10 | aljezur
# Processing Record 23 of Set 10 | atbasar
# Processing Record 24 of Set 10 | tilichiki
# Processing Record 25 of Set 10 | pinawa
# Processing Record 26 of Set 10 | makarov
# Processing Record 27 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 28 of Set 10 | nova vicosa
# Processing Record 29 of Set 10 | funadhoo
# Processing Record 30 of Set 10 | segezha
# Processing Record 31 of Set 10 | kieta
# Processing Record 32 of Set 10 | husavik
# Processing Record 33 of Set 10 | cap malheureux
# Processing Record 34 of Set 10 | yomou
# Processing Record 35 of Set 10 | karoi
# Processing Record 36 of Set 10 | pafos
# Processing Record 37 of Set 10 | cloquet
# Processing Record 38 of Set 10 | tahoua
# Processing Record 39 of Set 10 | araouane
# Processing Record 40 of Set 10 | serenje
# Processing Record 41 of Set 10 | quchan
# Processing Record 42 of Set 10 | lazaro cardenas
# Processing Record 43 of Set 10 | kloulklubed
# Processing Record 44 of Set 10 | trapani
# Processing Record 45 of Set 10 | linxia
# Processing Record 46 of Set 10 | novyy urengoy
# Processing Record 47 of Set 10 | coahuayana
# Processing Record 48 of Set 10 | oranjestad
# Processing Record 49 of Set 10 | mezen
# Processing Record 50 of Set 10 | demir kapija
# Processing Record 1 of Set 11 | flinders
# Processing Record 2 of Set 11 | kosh-agach
# Processing Record 3 of Set 11 | pacifica
# Processing Record 4 of Set 11 | honningsvag
# Processing Record 5 of Set 11 | kuytun
# Processing Record 6 of Set 11 | constitucion
# Processing Record 7 of Set 11 | fort nelson
# Processing Record 8 of Set 11 | poum
# Processing Record 9 of Set 11 | marsh harbour
# Processing Record 10 of Set 11 | coihaique
# Processing Record 11 of Set 11 | dodge city
# Processing Record 12 of Set 11 | miles city
# Processing Record 13 of Set 11 | seoul
# Processing Record 14 of Set 11 | chalus
# Processing Record 15 of Set 11 | charapan
# Processing Record 16 of Set 11 | berdigestyakh
# Processing Record 17 of Set 11 | turukhansk
# Processing Record 18 of Set 11 | belluru
# Processing Record 19 of Set 11 | pacific grove
# Processing Record 20 of Set 11 | laje
# Processing Record 21 of Set 11 | sistranda
# Processing Record 22 of Set 11 | naze
# Processing Record 23 of Set 11 | marsabit
# Processing Record 24 of Set 11 | dimbokro
# Processing Record 25 of Set 11 | quatre cocos
# Processing Record 26 of Set 11 | baherden
# Processing Record 27 of Set 11 | knysna
# Processing Record 28 of Set 11 | piacabucu
# Processing Record 29 of Set 11 | kayerkan
# Processing Record 30 of Set 11 | worthing
# Processing Record 31 of Set 11 | nantucket
# Processing Record 32 of Set 11 | loandjili
# Processing Record 33 of Set 11 | shache
# Processing Record 34 of Set 11 | bagdarin
# Processing Record 35 of Set 11 | grootfontein
# Processing Record 36 of Set 11 | sayyan
# Processing Record 37 of Set 11 | saint-augustin
# Processing Record 38 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 39 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 40 of Set 11 | okha
# Processing Record 41 of Set 11 | lakatoro
# Processing Record 42 of Set 11 | manacapuru
# Processing Record 43 of Set 11 | skibbereen
# Processing Record 44 of Set 11 | yarada
# Processing Record 45 of Set 11 | ferrol
# Processing Record 46 of Set 11 | garowe
# Processing Record 47 of Set 11 | mantua
# Processing Record 48 of Set 11 | chichester
# Processing Record 49 of Set 11 | mehamn
# Processing Record 50 of Set 11 | kisangani
# Processing Record 1 of Set 12 | chabahar
# Processing Record 2 of Set 12 | floro
# Processing Record 3 of Set 12 | nouadhibou
# Processing Record 4 of Set 12 | ulety
# Processing Record 5 of Set 12 | andra
# Processing Record 6 of Set 12 | vao
# Processing Record 7 of Set 12 | tatawin
# Processing Record 8 of Set 12 | kupang
# Processing Record 9 of Set 12 | lyngseidet
# Processing Record 10 of Set 12 | pishin
# Processing Record 11 of Set 12 | gat
# Processing Record 12 of Set 12 | nelson bay
# Processing Record 13 of Set 12 | eravur
# Processing Record 14 of Set 12 | santa margherita ligure
# Processing Record 15 of Set 12 | alyangula
# Processing Record 16 of Set 12 | jackson
# Processing Record 17 of Set 12 | odweyne
# Processing Record 18 of Set 12 | sturgis
# Processing Record 19 of Set 12 | mahibadhoo
# Processing Record 20 of Set 12 | sinnar
# Processing Record 21 of Set 12 | arlit
# Processing Record 22 of Set 12 | arkhangelsk
# Processing Record 23 of Set 12 | terra rica
# Processing Record 24 of Set 12 | glendive
# Processing Record 25 of Set 12 | lagoa
# Processing Record 26 of Set 12 | shitanjing
# Processing Record 27 of Set 12 | aasiaat
# Processing Record 28 of Set 12 | vestmannaeyjar
# Processing Record 29 of Set 12 | smolenka
# Processing Record 30 of Set 12 | waipawa
# Processing Record 31 of Set 12 | pajapan
# Processing Record 32 of Set 12 | phan thiet
# Processing Record 33 of Set 12 | ibague
# Processing Record 34 of Set 12 | hamilton
# Processing Record 35 of Set 12 | praia da vitoria
# Processing Record 36 of Set 12 | ajdabiya
# Processing Record 37 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 38 of Set 12 | antalaha
# Processing Record 39 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 40 of Set 12 | san quintin
# Processing Record 41 of Set 12 | yatou
# Processing Record 42 of Set 12 | thung song
# Processing Record 43 of Set 12 | bergama
# Processing Record 44 of Set 12 | mount pleasant
# Processing Record 45 of Set 12 | la plata
# Processing Record 46 of Set 12 | carutapera
# Processing Record 47 of Set 12 | bonfim
# Processing Record 48 of Set 12 | zwedru
# Processing Record 49 of Set 12 | mnogovershinnyy
# Processing Record 50 of Set 12 | orsk
# Processing Record 1 of Set 13 | whitehorse
# Processing Record 2 of Set 13 | rafaela
# Processing Record 3 of Set 13 | kon tum
# Processing Record 4 of Set 13 | howard springs
# Processing Record 5 of Set 13 | boueni
# Processing Record 6 of Set 13 | beitbridge
# Processing Record 7 of Set 13 | saurimo
# Processing Record 8 of Set 13 | nyurba
# Processing Record 9 of Set 13 | sarangani
# Processing Record 10 of Set 13 | nadym
# Processing Record 11 of Set 13 | tefe
# Processing Record 12 of Set 13 | vicuna
# Processing Record 13 of Set 13 | joshimath
# Processing Record 14 of Set 13 | usinsk
# Processing Record 15 of Set 13 | vostok
# Processing Record 16 of Set 13 | walla walla
# Processing Record 17 of Set 13 | baghdad
# Processing Record 18 of Set 13 | obo
# Processing Record 19 of Set 13 | veraval
# Processing Record 20 of Set 13 | visnes
# Processing Record 21 of Set 13 | ossora
# Processing Record 22 of Set 13 | augustow
# Processing Record 23 of Set 13 | palmer
# Processing Record 24 of Set 13 | vila velha
# Processing Record 25 of Set 13 | allanmyo
# City not found. Skipping...
# Processing Record 26 of Set 13 | mana
# Processing Record 27 of Set 13 | kaohsiung
# Processing Record 28 of Set 13 | mataram
# Processing Record 29 of Set 13 | bontang
# Processing Record 30 of Set 13 | bilibino
# Processing Record 31 of Set 13 | dauriya
# Processing Record 32 of Set 13 | emba
# Processing Record 33 of Set 13 | altoona
# Processing Record 34 of Set 13 | invermere
# Processing Record 35 of Set 13 | ola
# Processing Record 36 of Set 13 | aban
# Processing Record 37 of Set 13 | iqaluit
# Processing Record 38 of Set 13 | dingle
# Processing Record 39 of Set 13 | ginir
# Processing Record 40 of Set 13 | chapais
# Processing Record 41 of Set 13 | yinchuan
# Processing Record 42 of Set 13 | rio gallegos
# Processing Record 43 of Set 13 | sinkat
# City not found. Skipping...
# Processing Record 44 of Set 13 | fairbanks
# Processing Record 45 of Set 13 | kapit
# Processing Record 46 of Set 13 | hobbs
# Processing Record 47 of Set 13 | charters towers
# Processing Record 48 of Set 13 | vitim
# Processing Record 49 of Set 13 | itarema
# Processing Record 50 of Set 13 | khani
# Processing Record 1 of Set 14 | ambur
# Processing Record 2 of Set 14 | sena madureira
# Processing Record 3 of Set 14 | caxito
# Processing Record 4 of Set 14 | morondava
# Processing Record 5 of Set 14 | the valley
# Processing Record 6 of Set 14 | grande-riviere
# City not found. Skipping...
# Processing Record 7 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 8 of Set 14 | augusto correa
# Processing Record 9 of Set 14 | mahenge
# Processing Record 10 of Set 14 | merauke
# Processing Record 11 of Set 14 | ronne
# Processing Record 12 of Set 14 | barstow
# Processing Record 13 of Set 14 | tongchuan
# Processing Record 14 of Set 14 | san andres
# Processing Record 15 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 16 of Set 14 | zhezkazgan
# Processing Record 17 of Set 14 | pozoblanco
# Processing Record 18 of Set 14 | tezu
# Processing Record 19 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 20 of Set 14 | puerto quijarro
# Processing Record 21 of Set 14 | zhuhai
# Processing Record 22 of Set 14 | pimentel
# Processing Record 23 of Set 14 | fare
# Processing Record 24 of Set 14 | pitelino
# Processing Record 25 of Set 14 | lishui
# Processing Record 26 of Set 14 | sao joao da barra
# Processing Record 27 of Set 14 | krasnoturansk
# Processing Record 28 of Set 14 | nuevitas
# Processing Record 29 of Set 14 | fort morgan
# Processing Record 30 of Set 14 | salinopolis
# Processing Record 31 of Set 14 | sebrovo
# Processing Record 32 of Set 14 | atchison
# Processing Record 33 of Set 14 | togur
# Processing Record 34 of Set 14 | ulaangom
# Processing Record 35 of Set 14 | leshukonskoye
# Processing Record 36 of Set 14 | pergamino
# Processing Record 37 of Set 14 | juneau
# Processing Record 38 of Set 14 | ternate
# Processing Record 39 of Set 14 | atambua
# Processing Record 40 of Set 14 | olafsvik
# Processing Record 41 of Set 14 | oktyabrskoye
# Processing Record 42 of Set 14 | nampula
# Processing Record 43 of Set 14 | churapcha
# Processing Record 44 of Set 14 | tacoronte
# Processing Record 45 of Set 14 | high level
# Processing Record 46 of Set 14 | whangamata
# Processing Record 47 of Set 14 | nuuk
# Processing Record 48 of Set 14 | alexandria
# Processing Record 49 of Set 14 | awjilah
# Processing Record 50 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 2 of Set 15 | pangoa
# Processing Record 3 of Set 15 | anloga
# Processing Record 4 of Set 15 | szekesfehervar
# Processing Record 5 of Set 15 | high rock
# Processing Record 6 of Set 15 | kalmunai
# Processing Record 7 of Set 15 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 15 | aragats
# Processing Record 9 of Set 15 | okato
# Processing Record 10 of Set 15 | puerto escondido
# Processing Record 11 of Set 15 | tadine
# Processing Record 12 of Set 15 | saint-joseph
# Processing Record 13 of Set 15 | westport
# Processing Record 14 of Set 15 | sagua la grande
# Processing Record 15 of Set 15 | hofn
# Processing Record 16 of Set 15 | nylstroom
# City not found. Skipping...
# Processing Record 17 of Set 15 | manggar
# Processing Record 18 of Set 15 | algiers
# Processing Record 19 of Set 15 | tosno
# Processing Record 20 of Set 15 | aranos
# Processing Record 21 of Set 15 | smoky lake
# Processing Record 22 of Set 15 | maniitsoq
# Processing Record 23 of Set 15 | akita
# Processing Record 24 of Set 15 | gambela
# Processing Record 25 of Set 15 | agirish
# Processing Record 26 of Set 15 | kubachi
# Processing Record 27 of Set 15 | alugan
# Processing Record 28 of Set 15 | dali
# Processing Record 29 of Set 15 | portree
# Processing Record 30 of Set 15 | harwich
# Processing Record 31 of Set 15 | laureles
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
city_data
# Out:
# [{'City': 'Kokstad',
#   'Country': 'ZA',
#   'Lat': -30.55,
#   'Lng': 29.42,
#   'Max Temp': 74.77,
#   'Humidity': 44,
#   'Cloudiness': 41,
#   'Wind Speed': 11.34},
#  {'City': 'Gilgit',
#   'Country': 'PK',
#   'Lat': 35.92,
#   'Lng': 74.31,
#   'Max Temp': 70.75,
#   'Humidity': 23,
#   'Cloudiness': 65,
#   'Wind Speed': 6.62},
#  {'City': 'Busselton',
#   'Country': 'AU',
#   'Lat': -33.65,
#   'Lng': 115.33,
#   'Max Temp': 52,
#   'Humidity': 68,
#   'Cloudiness': 78,
#   'Wind Speed': 5.03},
#  {'City': 'Bethel',
#   'Country': 'US',
#   'Lat': 41.37,
#   'Lng': -73.41,
#   'Max Temp': 57.99,
#   'Humidity': 50,
#   'Cloudiness': 1,
#   'Wind Speed': 12.75},
#  {'City': 'Bud',
#   'Country': 'US',
#   'Lat': 39.45,
#   'Lng': -86.18,
#   'Max Temp': 66,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 5.68},
#  {'City': 'Cape Town',
#   'Country': 'ZA',
#   'Lat': -33.93,
#   'Lng': 18.42,
#   'Max Temp': 69.01,
#   'Humidity': 55,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05},
#  {'City': 'Rikitea',
#   'Country': 'PF',
#   'Lat': -23.12,
#   'Lng': -134.97,
#   'Max Temp': 73.11,
#   'Humidity': 80,
#   'Cloudiness': 52,
#   'Wind Speed': 17.72},
#  {'City': 'Provideniya',
#   'Country': 'RU',
#   'Lat': 64.38,
#   'Lng': -173.3,
#   'Max Temp': 41.18,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 9.6},
#  {'City': 'Hermanus',
#   'Country': 'ZA',
#   'Lat': -34.42,
#   'Lng': 19.23,
#   'Max Temp': 64.99,
#   'Humidity': 71,
#   'Cloudiness': 5,
#   'Wind Speed': 4},
#  {'City': 'Kavieng',
#   'Country': 'PG',
#   'Lat': -2.57,
#   'Lng': 150.8,
#   'Max Temp': 81.72,
#   'Humidity': 76,
#   'Cloudiness': 76,
#   'Wind Speed': 6.24},
#  {'City': 'Punta Arenas',
#   'Country': 'CL',
#   'Lat': -53.15,
#   'Lng': -70.92,
#   'Max Temp': 44.6,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 13.87},
#  {'City': 'Mahebourg',
#   'Country': 'MU',
#   'Lat': -20.41,
#   'Lng': 57.7,
#   'Max Temp': 77,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 11.41},
#  {'City': 'Lavrentiya',
#   'Country': 'RU',
#   'Lat': 65.58,
#   'Lng': -171,
#   'Max Temp': 40.91,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 21.77},
#  {'City': 'Avarua',
#   'Country': 'CK',
#   'Lat': -21.21,
#   'Lng': -159.78,
#   'Max Temp': 75.2,
#   'Humidity': 94,
#   'Cloudiness': 38,
#   'Wind Speed': 12.75},
#  {'City': 'Lahad Datu',
#   'Country': 'MY',
#   'Lat': 5.03,
#   'Lng': 118.33,
#   'Max Temp': 76.8,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 2.48},
#  {'City': 'Albany',
#   'Country': 'US',
#   'Lat': 42.6,
#   'Lng': -73.97,
#   'Max Temp': 52,
#   'Humidity': 58,
#   'Cloudiness': 48,
#   'Wind Speed': 1.99},
#  {'City': 'Zaqatala',
#   'Country': 'AZ',
#   'Lat': 41.63,
#   'Lng': 46.64,
#   'Max Temp': 66.2,
#   'Humidity': 52,
#   'Cloudiness': 20,
#   'Wind Speed': 2.24},
#  {'City': 'Kapaa',
#   'Country': 'US',
#   'Lat': 22.08,
#   'Lng': -159.32,
#   'Max Temp': 80.6,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 9.17},
#  {'City': 'Yellowknife',
#   'Country': 'CA',
#   'Lat': 62.46,
#   'Lng': -114.35,
#   'Max Temp': 35.6,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 9.17},
#  {'City': 'Mount Gambier',
#   'Country': 'AU',
#   'Lat': -37.83,
#   'Lng': 140.77,
#   'Max Temp': 50,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 16.11},
#  {'City': 'Zhangjiakou',
#   'Country': 'CN',
#   'Lat': 40.81,
#   'Lng': 114.88,
#   'Max Temp': 55.08,
#   'Humidity': 53,
#   'Cloudiness': 99,
#   'Wind Speed': 6.91},
#  {'City': 'Qaanaaq',
#   'Country': 'GL',
#   'Lat': 77.48,
#   'Lng': -69.36,
#   'Max Temp': 16.16,
#   'Humidity': 74,
#   'Cloudiness': 92,
#   'Wind Speed': 7.23},
#  {'City': 'Sibolga',
#   'Country': 'ID',
#   'Lat': 1.74,
#   'Lng': 98.78,
#   'Max Temp': 75.65,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 5.08},
#  {'City': 'Ushuaia',
#   'Country': 'AR',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 44.6,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82},
#  {'City': 'Skjervoy',
#   'Country': 'NO',
#   'Lat': 70.03,
#   'Lng': 20.97,
#   'Max Temp': 57.2,
#   'Humidity': 67,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11},
#  {'City': 'Hilo',
#   'Country': 'US',
#   'Lat': 19.73,
#   'Lng': -155.09,
#   'Max Temp': 70,
#   'Humidity': 60,
#   'Cloudiness': 1,
#   'Wind Speed': 3.56},
#  {'City': 'Hithadhoo',
#   'Country': 'MV',
#   'Lat': -0.6,
#   'Lng': 73.08,
#   'Max Temp': 82.72,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 11.5},
#  {'City': 'Palu',
#   'Country': 'ID',
#   'Lat': -0.89,
#   'Lng': 119.87,
#   'Max Temp': 77.32,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 2.98},
#  {'City': 'East London',
#   'Country': 'ZA',
#   'Lat': -33.02,
#   'Lng': 27.91,
#   'Max Temp': 69.8,
#   'Humidity': 83,
#   'Cloudiness': 52,
#   'Wind Speed': 13.87},
#  {'City': 'Alta Floresta',
#   'Country': 'BR',
#   'Lat': -9.88,
#   'Lng': -56.09,
#   'Max Temp': 114.49,
#   'Humidity': 15,
#   'Cloudiness': 0,
#   'Wind Speed': 0.78},
#  {'City': 'Benguela',
#   'Country': 'AO',
#   'Lat': -12.58,
#   'Lng': 13.41,
#   'Max Temp': 78.8,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93},
#  {'City': 'Upernavik',
#   'Country': 'GL',
#   'Lat': 72.79,
#   'Lng': -56.15,
#   'Max Temp': 31.68,
#   'Humidity': 88,
#   'Cloudiness': 31,
#   'Wind Speed': 8.75},
#  {'City': 'Nikolskoye',
#   'Country': 'RU',
#   'Lat': 59.7,
#   'Lng': 30.79,
#   'Max Temp': 57.2,
#   'Humidity': 82,
#   'Cloudiness': 90,
#   'Wind Speed': 4.47},
#  {'City': 'Taoudenni',
#   'Country': 'ML',
#   'Lat': 22.68,
#   'Lng': -3.98,
#   'Max Temp': 100.65,
#   'Humidity': 10,
#   'Cloudiness': 0,
#   'Wind Speed': 16.31},
#  {'City': 'Vila Franca Do Campo',
#   'Country': 'PT',
#   'Lat': 37.72,
#   'Lng': -25.43,
#   'Max Temp': 73.4,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05},
#  {'City': 'Novo Aripuana',
#   'Country': 'BR',
#   'Lat': -5.12,
#   'Lng': -60.38,
#   'Max Temp': 98.38,
#   'Humidity': 35,
#   'Cloudiness': 17,
#   'Wind Speed': 3.24},
#  {'City': 'Bengkulu',
#   'Country': 'ID',
#   'Lat': -3.8,
#   'Lng': 102.27,
#   'Max Temp': 74.68,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 6.4},
#  {'City': 'Bredasdorp',
#   'Country': 'ZA',
#   'Lat': -34.53,
#   'Lng': 20.04,
#   'Max Temp': 68,
#   'Humidity': 52,
#   'Cloudiness': 56,
#   'Wind Speed': 14.99},
#  {'City': 'Jinji',
#   'Country': 'CN',
#   'Lat': 23.23,
#   'Lng': 110.83,
#   'Max Temp': 65.43,
#   'Humidity': 76,
#   'Cloudiness': 18,
#   'Wind Speed': 3.56},
#  {'City': 'Kaitangata',
#   'Country': 'NZ',
#   'Lat': -46.28,
#   'Lng': 169.85,
#   'Max Temp': 42.01,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 1.99},
#  {'City': 'Chokurdakh',
#   'Country': 'RU',
#   'Lat': 70.63,
#   'Lng': 147.92,
#   'Max Temp': 23.54,
#   'Humidity': 90,
#   'Cloudiness': 86,
#   'Wind Speed': 7.63},
#  {'City': 'Bluff',
#   'Country': 'NZ',
#   'Lat': -46.6,
#   'Lng': 168.33,
#   'Max Temp': 35.01,
#   'Humidity': 89,
#   'Cloudiness': 0,
#   'Wind Speed': 8.1},
#  {'City': 'Mataura',
#   'Country': 'NZ',
#   'Lat': -46.19,
#   'Lng': 168.86,
#   'Max Temp': 35.01,
#   'Humidity': 89,
#   'Cloudiness': 1,
#   'Wind Speed': 2.82},
#  {'City': 'New Norfolk',
#   'Country': 'AU',
#   'Lat': -42.78,
#   'Lng': 147.06,
#   'Max Temp': 51.01,
#   'Humidity': 92,
#   'Cloudiness': 67,
#   'Wind Speed': 1.63},
#  {'City': 'Lincoln',
#   'Country': 'US',
#   'Lat': 40.8,
#   'Lng': -96.67,
#   'Max Temp': 64,
#   'Humidity': 48,
#   'Cloudiness': 20,
#   'Wind Speed': 5.99},
#  {'City': 'Bambous Virieux',
#   'Country': 'MU',
#   'Lat': -20.34,
#   'Lng': 57.76,
#   'Max Temp': 77,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 11.41},
#  {'City': 'Talnakh',
#   'Country': 'RU',
#   'Lat': 69.49,
#   'Lng': 88.4,
#   'Max Temp': 30.2,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 8.95},
#  {'City': 'Tamandare',
#   'Country': 'BR',
#   'Lat': -8.76,
#   'Lng': -35.1,
#   'Max Temp': 83.03,
#   'Humidity': 66,
#   'Cloudiness': 27,
#   'Wind Speed': 10.6},
#  {'City': 'Buala',
#   'Country': 'SB',
#   'Lat': -8.14,
#   'Lng': 159.59,
#   'Max Temp': 80.08,
#   'Humidity': 82,
#   'Cloudiness': 99,
#   'Wind Speed': 6.91},
#  {'City': 'Ponta Do Sol',
#   'Country': 'PT',
#   'Lat': 32.67,
#   'Lng': -17.1,
#   'Max Temp': 73.4,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7},
#  {'City': 'Bourail',
#   'Country': 'NC',
#   'Lat': -21.57,
#   'Lng': 165.48,
#   'Max Temp': 68.61,
#   'Humidity': 87,
#   'Cloudiness': 41,
#   'Wind Speed': 2.84},
#  {'City': 'Morgan City',
#   'Country': 'US',
#   'Lat': 29.7,
#   'Lng': -91.21,
#   'Max Temp': 78.01,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 9.17},
#  {'City': 'Sao Filipe',
#   'Country': 'CV',
#   'Lat': 14.9,
#   'Lng': -24.5,
#   'Max Temp': 82.09,
#   'Humidity': 78,
#   'Cloudiness': 55,
#   'Wind Speed': 9.6},
#  {'City': 'Port Elizabeth',
#   'Country': 'ZA',
#   'Lat': -33.92,
#   'Lng': 25.57,
#   'Max Temp': 68,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 13.87},
#  {'City': 'Malinovoye Ozero',
#   'Country': 'RU',
#   'Lat': 51.68,
#   'Lng': 79.78,
#   'Max Temp': 33.24,
#   'Humidity': 88,
#   'Cloudiness': 83,
#   'Wind Speed': 8.48},
#  {'City': 'Arraial Do Cabo',
#   'Country': 'BR',
#   'Lat': -22.97,
#   'Lng': -42.03,
#   'Max Temp': 75.2,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36},
#  {'City': 'Tuatapere',
#   'Country': 'NZ',
#   'Lat': -46.13,
#   'Lng': 167.68,
#   'Max Temp': 35.01,
#   'Humidity': 89,
#   'Cloudiness': 1,
#   'Wind Speed': 4.23},
#  {'City': 'Puerto Ayora',
#   'Country': 'EC',
#   'Lat': -0.74,
#   'Lng': -90.35,
#   'Max Temp': 66,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 4},
#  {'City': 'Ankazoabo',
#   'Country': 'MG',
#   'Lat': -22.28,
#   'Lng': 44.52,
#   'Max Temp': 82.36,
#   'Humidity': 23,
#   'Cloudiness': 7,
#   'Wind Speed': 9.95},
#  {'City': 'Saint-Marc',
#   'Country': 'HT',
#   'Lat': 19.11,
#   'Lng': -72.69,
#   'Max Temp': 83.23,
#   'Humidity': 64,
#   'Cloudiness': 43,
#   'Wind Speed': 2.8},
#  {'City': 'Butaritari',
#   'Country': 'KI',
#   'Lat': 3.07,
#   'Lng': 172.79,
#   'Max Temp': 82.09,
#   'Humidity': 78,
#   'Cloudiness': 3,
#   'Wind Speed': 14.7},
#  {'City': 'Tuktoyaktuk',
#   'Country': 'CA',
#   'Lat': 69.45,
#   'Lng': -133.04,
#   'Max Temp': 32,
#   'Humidity': 97,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29},
#  {'City': 'Pevek',
#   'Country': 'RU',
#   'Lat': 69.7,
#   'Lng': 170.31,
#   'Max Temp': 31.87,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 15.21},
#  {'City': 'Khatanga',
#   'Country': 'RU',
#   'Lat': 71.97,
#   'Lng': 102.5,
#   'Max Temp': 19.58,
#   'Humidity': 97,
#   'Cloudiness': 81,
#   'Wind Speed': 10.29},
#  {'City': 'Winslow',
#   'Country': 'US',
#   'Lat': 35.02,
#   'Lng': -110.7,
#   'Max Temp': 48.2,
#   'Humidity': 21,
#   'Cloudiness': 1,
#   'Wind Speed': 6.93},
#  {'City': 'Barrow',
#   'Country': 'US',
#   'Lat': 71.29,
#   'Lng': -156.79,
#   'Max Temp': 32,
#   'Humidity': 96,
#   'Cloudiness': 90,
#   'Wind Speed': 26.4},
#  {'City': 'Mitsamiouli',
#   'Country': 'KM',
#   'Lat': -11.38,
#   'Lng': 43.28,
#   'Max Temp': 78.06,
#   'Humidity': 79,
#   'Cloudiness': 49,
#   'Wind Speed': 8.25},
#  {'City': 'Mount Isa',
#   'Country': 'AU',
#   'Lat': -20.73,
#   'Lng': 139.5,
#   'Max Temp': 73.4,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 11.41},
#  {'City': 'Abong Mbang',
#   'Country': 'CM',
#   'Lat': 3.98,
#   'Lng': 13.18,
#   'Max Temp': 76.53,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 2.26},
#  {'City': 'Ostrovnoy',
#   'Country': 'RU',
#   'Lat': 68.05,
#   'Lng': 39.51,
#   'Max Temp': 47.73,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 13.15},
#  {'City': 'Ixtapa',
#   'Country': 'MX',
#   'Lat': 20.7,
#   'Lng': -105.2,
#   'Max Temp': 82,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7},
#  {'City': 'Port Moresby',
#   'Country': 'PG',
#   'Lat': -9.44,
#   'Lng': 147.18,
#   'Max Temp': 77,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 17.22},
#  {'City': 'Saint George',
#   'Country': 'US',
#   'Lat': 37.1,
#   'Lng': -113.58,
#   'Max Temp': 57.2,
#   'Humidity': 16,
#   'Cloudiness': 1,
#   'Wind Speed': 4.7},
#  {'City': 'Baykit',
#   'Country': 'RU',
#   'Lat': 61.67,
#   'Lng': 96.37,
#   'Max Temp': 26.2,
#   'Humidity': 91,
#   'Cloudiness': 61,
#   'Wind Speed': 5.41},
#  {'City': 'Lata',
#   'Country': 'PT',
#   'Lat': 40.16,
#   'Lng': -8.33,
#   'Max Temp': 79,
#   'Humidity': 57,
#   'Cloudiness': 67,
#   'Wind Speed': 7.27},
#  {'City': 'Asau',
#   'Country': 'RO',
#   'Lat': 46.43,
#   'Lng': 26.4,
#   'Max Temp': 61,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 3.94},
#  {'City': 'Jamestown',
#   'Country': 'US',
#   'Lat': 42.1,
#   'Lng': -79.24,
#   'Max Temp': 52,
#   'Humidity': 66,
#   'Cloudiness': 75,
#   'Wind Speed': 14.99},
#  {'City': 'Saskylakh',
#   'Country': 'RU',
#   'Lat': 71.92,
#   'Lng': 114.08,
#   'Max Temp': 13.6,
#   'Humidity': 91,
#   'Cloudiness': 66,
#   'Wind Speed': 10.58},
#  {'City': 'Lompoc',
#   'Country': 'US',
#   'Lat': 34.64,
#   'Lng': -120.46,
#   'Max Temp': 57.2,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 5.08},
#  {'City': 'Clyde River',
#   'Country': 'CA',
#   'Lat': 70.47,
#   'Lng': -68.59,
#   'Max Temp': 26.6,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05},
#  {'City': 'Atuona',
#   'Country': 'PF',
#   'Lat': -9.8,
#   'Lng': -139.03,
#   'Max Temp': 77.54,
#   'Humidity': 76,
#   'Cloudiness': 1,
#   'Wind Speed': 20.33},
#  {'City': 'Port Alfred',
#   'Country': 'ZA',
#   'Lat': -33.59,
#   'Lng': 26.89,
#   'Max Temp': 68.45,
#   'Humidity': 76,
#   'Cloudiness': 62,
#   'Wind Speed': 12.17},
#  {'City': 'Bereda',
#   'Country': 'ES',
#   'Lat': 43.27,
#   'Lng': -7.54,
#   'Max Temp': 73.99,
#   'Humidity': 70,
#   'Cloudiness': 88,
#   'Wind Speed': 1.01},
#  {'City': 'Leningradskiy',
#   'Country': 'RU',
#   'Lat': 69.38,
#   'Lng': 178.42,
#   'Max Temp': 32.49,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 15.84},
#  {'City': 'Nago',
#   'Country': 'JP',
#   'Lat': 26.59,
#   'Lng': 127.98,
#   'Max Temp': 75.2,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05},
#  {'City': 'Camacha',
#   'Country': 'PT',
#   'Lat': 33.08,
#   'Lng': -16.33,
#   'Max Temp': 73.4,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 5.82},
#  {'City': 'Hobart',
#   'Country': 'AU',
#   'Lat': -42.88,
#   'Lng': 147.33,
#   'Max Temp': 51.01,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 3.8},
#  {'City': 'Saint-Philippe',
#   'Country': 'RE',
#   'Lat': -21.36,
#   'Lng': 55.77,
#   'Max Temp': 77,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 2.24},
#  {'City': 'Hambantota',
#   'Country': 'LK',
#   'Lat': 6.12,
#   'Lng': 81.12,
#   'Max Temp': 82.4,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 11.41},
#  {'City': 'Aksu',
#   'Country': 'CN',
#   'Lat': 41.12,
#   'Lng': 80.26,
#   'Max Temp': 54.88,
#   'Humidity': 36,
#   'Cloudiness': 27,
#   'Wind Speed': 4.41},
#  {'City': 'Saldanha',
#   'Country': 'ZA',
#   'Lat': -33.01,
#   'Lng': 17.94,
#   'Max Temp': 68,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11},
#  {'City': 'Vaini',
#   'Country': 'TO',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 69.8,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 8.63},
#  {'City': 'Rio Grande',
#   'Country': 'BR',
#   'Lat': -32.03,
#   'Lng': -52.1,
#   'Max Temp': 63,
#   'Humidity': 91,
#   'Cloudiness': 87,
#   'Wind Speed': 7.96},
#  {'City': 'Ranong',
#   'Country': 'TH',
#   'Lat': 9.97,
#   'Lng': 98.63,
#   'Max Temp': 78.22,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 3.13},
#  {'City': 'Ribeira Grande',
#   'Country': 'PT',
#   'Lat': 38.52,
#   'Lng': -28.7,
#   'Max Temp': 73.4,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 5.82},
#  {'City': 'Conde',
#   'Country': 'BR',
#   'Lat': -7.26,
#   'Lng': -34.91,
#   'Max Temp': 87.8,
#   'Humidity': 58,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29},
#  {'City': 'Kalengwa',
#   'Country': 'ZM',
#   'Lat': -13.47,
#   'Lng': 25,
#   'Max Temp': 83.46,
#   'Humidity': 39,
#   'Cloudiness': 69,
#   'Wind Speed': 7.76},
#  {'City': 'Trinidad',
#   'Country': 'BO',
#   'Lat': -14.83,
#   'Lng': -64.9,
#   'Max Temp': 87.8,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 10.29},
#  {'City': 'Easton',
#   'Country': 'US',
#   'Lat': 40.69,
#   'Lng': -75.22,
#   'Max Temp': 60.01,
#   'Humidity': 58,
#   'Cloudiness': 1,
#   'Wind Speed': 11.41},
#  {'City': 'Asosa',
#   'Country': 'ET',
#   'Lat': 10.07,
#   'Lng': 34.53,
#   'Max Temp': 69.94,
#   'Humidity': 86,
#   'Cloudiness': 4,
#   'Wind Speed': 1.63},
#  {'City': 'Sulangan',
#   'Country': 'PH',
#   'Lat': 11.14,
#   'Lng': 123.72,
#   'Max Temp': 81.32,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 2.39},
#  {'City': 'Nemuro',
#   'Country': 'JP',
#   'Lat': 43.32,
#   'Lng': 145.57,
#   'Max Temp': 54.07,
#   'Humidity': 75,
#   'Cloudiness': 90,
#   'Wind Speed': 6.31},
#  {'City': 'Port Lincoln',
#   'Country': 'AU',
#   'Lat': -34.73,
#   'Lng': 135.87,
#   'Max Temp': 51.22,
#   'Humidity': 83,
#   'Cloudiness': 99,
#   'Wind Speed': 7.99},
#  {'City': 'Prince Rupert',
#   'Country': 'CA',
#   'Lat': 54.32,
#   'Lng': -130.32,
#   'Max Temp': 41,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7},
#  {'City': 'Evensk',
#   'Country': 'RU',
#   'Lat': 61.95,
#   'Lng': 159.23,
#   'Max Temp': 31.33,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 9.93},
#  {'City': 'Warrnambool',
#   'Country': 'AU',
#   'Lat': -38.38,
#   'Lng': 142.48,
#   'Max Temp': 52,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 10},
#  {'City': 'Raudeberg',
#   'Country': 'NO',
#   'Lat': 61.99,
#   'Lng': 5.14,
#   'Max Temp': 53.01,
#   'Humidity': 88,
#   'Cloudiness': 98,
#   'Wind Speed': 7.65},
#  {'City': 'Chuy',
#   'Country': 'UY',
#   'Lat': -33.7,
#   'Lng': -53.46,
#   'Max Temp': 62.69,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 6.26},
#  {'City': 'Marystown',
#   'Country': 'CA',
#   'Lat': 47.17,
#   'Lng': -55.15,
#   'Max Temp': 59,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 8.01},
#  {'City': 'Verkhoyansk',
#   'Country': 'RU',
#   'Lat': 67.54,
#   'Lng': 133.38,
#   'Max Temp': 26.38,
#   'Humidity': 95,
#   'Cloudiness': 15,
#   'Wind Speed': 2.82},
#  {'City': 'Arambagh',
#   'Country': 'IN',
#   'Lat': 22.88,
#   'Lng': 87.78,
#   'Max Temp': 81.39,
#   'Humidity': 84,
#   'Cloudiness': 45,
#   'Wind Speed': 6.26},
#  {'City': 'Tautira',
#   'Country': 'PF',
#   'Lat': -17.73,
#   'Lng': -149.15,
#   'Max Temp': 75.2,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 3.36},
#  {'City': 'Mar Del Plata',
#   'Country': 'AR',
#   'Lat': -38,
#   'Lng': -57.56,
#   'Max Temp': 57.2,
#   'Humidity': 41,
#   'Cloudiness': 0,
#   'Wind Speed': 6.93},
#  {'City': 'Sarkand',
#   'Country': 'KZ',
#   'Lat': 45.41,
#   'Lng': 79.92,
#   'Max Temp': 40.69,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 2.33},
#  {'City': 'Saint Anthony',
#   'Country': 'US',
#   'Lat': 45.02,
#   'Lng': -93.22,
#   'Max Temp': 55,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 5.82},
#  {'City': 'Barcelos',
#   'Country': 'PT',
#   'Lat': 41.54,
#   'Lng': -8.62,
#   'Max Temp': 73.99,
#   'Humidity': 77,
#   'Cloudiness': 2,
#   'Wind Speed': 8.05},
#  {'City': 'Zhigansk',
#   'Country': 'RU',
#   'Lat': 66.77,
#   'Lng': 123.37,
#   'Max Temp': 29.37,
#   'Humidity': 98,
#   'Cloudiness': 97,
#   'Wind Speed': 8.25},
#  {'City': 'Buchanan',
#   'Country': 'LR',
#   'Lat': 5.88,
#   'Lng': -10.05,
#   'Max Temp': 82.4,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82},
#  {'City': 'Padang',
#   'Country': 'ID',
#   'Lat': -0.95,
#   'Lng': 100.35,
#   'Max Temp': 76.3,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 7.16},
#  {'City': 'La Ronge',
#   'Country': 'CA',
#   'Lat': 55.1,
#   'Lng': -105.28,
#   'Max Temp': 42.8,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 11.41},
#  {'City': 'Cueramaro',
#   'Country': 'MX',
#   'Lat': 20.62,
#   'Lng': -101.72,
#   'Max Temp': 51.8,
#   'Humidity': 66,
#   'Cloudiness': 40,
#   'Wind Speed': 2.26},
#  {'City': 'Sakakah',
#   'Country': 'SA',
#   'Lat': 29.97,
#   'Lng': 40.21,
#   'Max Temp': 95,
#   'Humidity': 8,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7},
#  {'City': 'Aklavik',
#   'Country': 'CA',
#   'Lat': 68.22,
#   'Lng': -135.01,
#   'Max Temp': 35.6,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05},
#  {'City': 'Marsa Matruh',
#   'Country': 'EG',
#   'Lat': 31.35,
#   'Lng': 27.25,
#   'Max Temp': 84.2,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 6.93},
#  {'City': 'Dunmore Town',
#   'Country': 'BS',
#   'Lat': 25.5,
#   'Lng': -76.65,
#   'Max Temp': 81.59,
#   'Humidity': 77,
#   'Cloudiness': 28,
#   'Wind Speed': 13.69},
#  {'City': 'Port-Gentil',
#   'Country': 'GA',
#   'Lat': -0.72,
#   'Lng': 8.78,
#   'Max Temp': 84.2,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 9.17},
#  {'City': 'Thompson',
#   'Country': 'CA',
#   'Lat': 55.74,
#   'Lng': -97.86,
#   'Max Temp': 30.2,
#   'Humidity': 80,
#   'Cloudiness': 90,
#   'Wind Speed': 4.7},
#  {'City': 'Coruripe',
#   'Country': 'BR',
#   'Lat': -10.13,
#   'Lng': -36.18,
#   'Max Temp': 84.06,
#   'Humidity': 66,
#   'Cloudiness': 27,
#   'Wind Speed': 14.2},
#  {'City': 'Impfondo',
#   'Country': 'CG',
#   'Lat': 1.64,
#   'Lng': 18.07,
#   'Max Temp': 78.84,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 2.28},
#  {'City': 'Haines Junction',
#   'Country': 'CA',
#   'Lat': 60.75,
#   'Lng': -137.51,
#   'Max Temp': 35.4,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 1.21},
#  {'City': 'Mandalgovi',
#   'Country': 'MN',
#   'Lat': 45.76,
#   'Lng': 106.27,
#   'Max Temp': 38.43,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05},
#  {'City': 'Honavar',
#   'Country': 'IN',
#   'Lat': 14.28,
#   'Lng': 74.45,
#   'Max Temp': 79.23,
#   'Humidity': 89,
#   'Cloudiness': 0,
#   'Wind Speed': 4.59},
#  {'City': 'Mbigou',
#   'Country': 'GA',
#   'Lat': -1.9,
#   'Lng': 11.91,
#   'Max Temp': 77.43,
#   'Humidity': 74,
#   'Cloudiness': 97,
#   'Wind Speed': 3.42},
#  {'City': 'Victoria',
#   'Country': 'HK',
#   'Lat': 22.29,
#   'Lng': 114.16,
#   'Max Temp': 78.01,
#   'Humidity': 67,
#   'Cloudiness': 30,
#   'Wind Speed': 10.6},
#  {'City': 'Salalah',
#   'Country': 'OM',
#   'Lat': 17.02,
#   'Lng': 54.09,
#   'Max Temp': 80.6,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 5.82},
#  {'City': 'Carnarvon',
#   'Country': 'AU',
#   'Lat': -24.87,
#   'Lng': 113.63,
#   'Max Temp': 66.2,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 12.75},
#  {'City': 'Brookings',
#   'Country': 'US',
#   'Lat': 44.31,
#   'Lng': -96.8,
#   'Max Temp': 54,
#   'Humidity': 53,
#   'Cloudiness': 1,
#   'Wind Speed': 10.29},
#  {'City': 'Gao',
#   'Country': 'ML',
#   'Lat': 16.64,
#   'Lng': 1.64,
#   'Max Temp': 102.61,
#   'Humidity': 18,
#   'Cloudiness': 0,
#   'Wind Speed': 8.14},
#  {'City': 'Ketchikan',
#   'Country': 'US',
#   'Lat': 55.34,
#   'Lng': -131.65,
#   'Max Temp': 41,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 2.62},
#  {'City': 'Jalu',
#   'Country': 'LY',
#   'Lat': 29.03,
#   'Lng': 21.55,
#   'Max Temp': 96.66,
#   'Humidity': 17,
#   'Cloudiness': 0,
#   'Wind Speed': 14.63},
#  {'City': 'Zlobin',
#   'Country': 'HR',
#   'Lat': 45.29,
#   'Lng': 14.65,
#   'Max Temp': 68,
#   'Humidity': 52,
#   'Cloudiness': 20,
#   'Wind Speed': 4.7},
#  {'City': 'Tasiilaq',
#   'Country': 'GL',
#   'Lat': 65.61,
#   'Lng': -37.64,
#   'Max Temp': 39.2,
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 1.12},
#  {'City': 'Xinqing',
#   'Country': 'CN',
#   'Lat': 48.23,
#   'Lng': 129.5,
#   'Max Temp': 37.44,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 1.23},
#  {'City': 'Talcahuano',
#   'Country': 'CL',
#   'Lat': -36.72,
#   'Lng': -73.12,
#   'Max Temp': 57.2,
#   'Humidity': 62,
#   'Cloudiness': 57,
#   'Wind Speed': 9.17},
#  {'City': 'North Bend',
#   'Country': 'US',
#   'Lat': 43.41,
#   'Lng': -124.22,
#   'Max Temp': 57,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 3.36},
#  {'City': 'Castro',
#   'Country': 'BR',
#   'Lat': -24.79,
#   'Lng': -50.01,
#   'Max Temp': 88.77,
#   'Humidity': 36,
#   'Cloudiness': 24,
#   'Wind Speed': 11.77},
#  {'City': 'Shyryayeve',
#   'Country': 'UA',
#   'Lat': 47.38,
#   'Lng': 30.2,
#   'Max Temp': 68.65,
#   'Humidity': 56,
#   'Cloudiness': 100,
#   'Wind Speed': 6.73},
#  {'City': 'Erzin',
#   'Country': 'TR',
#   'Lat': 36.96,
#   'Lng': 36.2,
#   'Max Temp': 86,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 2.17},
#  {'City': 'Kyren',
#   'Country': 'RU',
#   'Lat': 51.68,
#   'Lng': 102.14,
#   'Max Temp': 32.52,
#   'Humidity': 93,
#   'Cloudiness': 83,
#   'Wind Speed': 1.3},
#  {'City': 'Pangody',
#   'Country': 'RU',
#   'Lat': 65.85,
#   'Lng': 74.49,
#   'Max Temp': 32.56,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 14.92},
#  {'City': 'Bressanone',
#   'Country': 'IT',
#   'Lat': 46.72,
#   'Lng': 11.66,
#   'Max Temp': 68,
#   'Humidity': 42,
#   'Cloudiness': 20,
#   'Wind Speed': 2.24},
#  {'City': 'Laguna',
#   'Country': 'US',
#   'Lat': 38.42,
#   'Lng': -121.42,
#   'Max Temp': 57.99,
#   'Humidity': 82,
#   'Cloudiness': 1,
#   'Wind Speed': 6.93},
#  {'City': 'Linjiang',
#   'Country': 'CN',
#   'Lat': 41.81,
#   'Lng': 126.91,
#   'Max Temp': 47.66,
#   'Humidity': 71,
#   'Cloudiness': 39,
#   'Wind Speed': 1.95},
#  {'City': 'Nome',
#   'Country': 'US',
#   'Lat': 64.5,
#   'Lng': -165.41,
#   'Max Temp': 45,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 21.92},
#  {'City': 'Dongsheng',
#   'Country': 'CN',
#   'Lat': 39.82,
#   'Lng': 109.98,
#   'Max Temp': 49.35,
#   'Humidity': 84,
#   'Cloudiness': 1,
#   'Wind Speed': 14.45},
#  {'City': 'Southbridge',
#   'Country': 'US',
#   'Lat': 42.08,
#   'Lng': -72.03,
#   'Max Temp': 54,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 3},
#  {'City': 'Sisimiut',
#   'Country': 'GL',
#   'Lat': 66.94,
#   'Lng': -53.67,
#   'Max Temp': 34.77,
#   'Humidity': 75,
#   'Cloudiness': 73,
#   'Wind Speed': 15.68},
#  {'City': 'Mendeleyevskiy',
#   'Country': 'RU',
#   'Lat': 54.15,
#   'Lng': 37.58,
#   'Max Temp': 56.86,
#   'Humidity': 40,
#   'Cloudiness': 95,
#   'Wind Speed': 9.44},
#  {'City': 'Vila Do Maio',
#   'Country': 'CV',
#   'Lat': 15.13,
#   'Lng': -23.22,
#   'Max Temp': 75.2,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 14.99},
#  {'City': 'Vratnica',
#   'Country': 'MK',
#   'Lat': 42.14,
#   'Lng': 21.12,
#   'Max Temp': 59,
#   'Humidity': 58,
#   'Cloudiness': 90,
#   'Wind Speed': 3.36},
#  {'City': 'Kailua',
#   'Country': 'US',
#   'Lat': 21.4,
#   'Lng': -157.74,
#   'Max Temp': 78.8,
#   'Humidity': 69,
#   'Cloudiness': 1,
#   'Wind Speed': 3.36},
#  {'City': 'Wuwei',
#   'Country': 'CN',
#   'Lat': 37.93,
#   'Lng': 102.64,
#   'Max Temp': 51.48,
#   'Humidity': 44,
#   'Cloudiness': 0,
#   'Wind Speed': 2.57},
#  {'City': 'Batemans Bay',
#   'Country': 'AU',
#   'Lat': -35.72,
#   'Lng': 150.18,
#   'Max Temp': 55.99,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 5.99},
#  {'City': 'Baruun-Urt',
#   'Country': 'MN',
#   'Lat': 46.68,
#   'Lng': 113.28,
#   'Max Temp': 43.16,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 10.69},
#  {'City': 'Candolim',
#   'Country': 'IN',
#   'Lat': 15.52,
#   'Lng': 73.76,
#   'Max Temp': 82.4,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 11.41},
#  {'City': 'Wad Rawah',
#   'Country': 'SD',
#   'Lat': 15.16,
#   'Lng': 33.14,
#   'Max Temp': 102.6,
#   'Humidity': 14,
#   'Cloudiness': 47,
#   'Wind Speed': 4.59},
#  {'City': 'Shenjiamen',
#   'Country': 'CN',
#   'Lat': 29.96,
#   'Lng': 122.3,
#   'Max Temp': 69.06,
#   'Humidity': 72,
#   'Cloudiness': 90,
#   'Wind Speed': 18.68},
#  {'City': 'San Patricio',
#   'Country': 'US',
#   'Lat': 28.02,
#   'Lng': -97.52,
#   'Max Temp': 81,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05},
#  {'City': 'Riyadh',
#   'Country': 'SA',
#   'Lat': 24.69,
#   'Lng': 46.72,
#   'Max Temp': 95,
#   'Humidity': 14,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82},
#  {'City': 'Poya',
#   'Country': 'NC',
#   'Lat': -21.35,
#   'Lng': 165.15,
#   'Max Temp': 68.72,
#   'Humidity': 87,
#   'Cloudiness': 27,
#   'Wind Speed': 3.42},
#  {'City': 'Pinerolo',
#   'Country': 'IT',
#   'Lat': 44.88,
#   'Lng': 7.35,
#   'Max Temp': 70,
#   'Humidity': 40,
#   'Cloudiness': 63,
#   'Wind Speed': 1.01},
#  {'City': 'Kahului',
#   'Country': 'US',
#   'Lat': 20.89,
#   'Lng': -156.47,
#   'Max Temp': 73.99,
#   'Humidity': 73,
#   'Cloudiness': 1,
#   'Wind Speed': 7.07},
#  {'City': 'Madang',
#   'Country': 'PG',
#   'Lat': -5.22,
#   'Lng': 145.8,
#   'Max Temp': 78.37,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 3.58},
#  {'City': 'Kidal',
#   'Country': 'ML',
#   'Lat': 18.44,
#   'Lng': 1.41,
#   'Max Temp': 104.09,
#   'Humidity': 8,
#   'Cloudiness': 0,
#   'Wind Speed': 4.18},
#  {'City': 'Banda Aceh',
#   'Country': 'ID',
#   'Lat': 5.56,
#   'Lng': 95.32,
#   'Max Temp': 80.38,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 13.42},
#  {'City': 'Lorengau',
#   'Country': 'PG',
#   'Lat': -2.02,
#   'Lng': 147.27,
#   'Max Temp': 80.89,
#   'Humidity': 79,
#   'Cloudiness': 36,
#   'Wind Speed': 3.33},
#  {'City': 'Venezuela',
#   'Country': 'VE',
#   'Lat': 8,
#   'Lng': -66,
#   'Max Temp': 87.1,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 12.59},
#  {'City': 'Touros',
#   'Country': 'BR',
#   'Lat': -5.2,
#   'Lng': -35.46,
#   'Max Temp': 86,
#   'Humidity': 58,
#   'Cloudiness': 75,
#   'Wind Speed': 13.87},
#  {'City': 'Adigeni',
#   'Country': 'GE',
#   'Lat': 41.68,
#   'Lng': 42.7,
#   'Max Temp': 75.2,
#   'Humidity': 31,
#   'Cloudiness': 0,
#   'Wind Speed': 29.97},
#  {'City': 'Grand Gaube',
#   'Country': 'MU',
#   'Lat': -20.01,
#   'Lng': 57.66,
#   'Max Temp': 75.99,
#   'Humidity': 80,
#   'Cloudiness': 24,
#   'Wind Speed': 4},
#  {'City': 'Yeniseysk',
#   'Country': 'RU',
#   'Lat': 58.45,
#   'Lng': 92.17,
#   'Max Temp': 28.31,
#   'Humidity': 93,
#   'Cloudiness': 89,
#   'Wind Speed': 3.15},
#  {'City': 'Namibe',
#   'Country': 'AO',
#   'Lat': -15.2,
#   'Lng': 12.15,
#   'Max Temp': 75.2,
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 16.11},
#  {'City': 'Bati',
#   'Country': 'ET',
#   'Lat': 11.18,
#   'Lng': 40.02,
#   'Max Temp': 72.07,
#   'Humidity': 44,
#   'Cloudiness': 94,
#   'Wind Speed': 7.85},
#  {'City': 'Sambava',
#   'Country': 'MG',
#   'Lat': -14.27,
#   'Lng': 50.17,
#   'Max Temp': 76.44,
#   'Humidity': 79,
#   'Cloudiness': 94,
#   'Wind Speed': 3.67},
#  {'City': 'Guerrero Negro',
#   'Country': 'MX',
#   'Lat': 27.98,
#   'Lng': -114.06,
#   'Max Temp': 73.26,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 13.73},
#  {'City': 'Chochola',
#   'Country': 'MX',
#   'Lat': 20.75,
#   'Lng': -89.83,
#   'Max Temp': 78.01,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 10.29},
#  {'City': 'Grindavik',
#   'Country': 'IS',
#   'Lat': 63.84,
#   'Lng': -22.43,
#   'Max Temp': 42.8,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93},
#  {'City': 'Bulawayo',
#   'Country': 'ZW',
#   'Lat': -20.15,
#   'Lng': 28.58,
#   'Max Temp': 80.04,
#   'Humidity': 41,
#   'Cloudiness': 15,
#   'Wind Speed': 8.81},
#  {'City': 'Caravelas',
#   'Country': 'BR',
#   'Lat': -17.71,
#   'Lng': -39.25,
#   'Max Temp': 85.87,
#   'Humidity': 60,
#   'Cloudiness': 1,
#   'Wind Speed': 12.3},
#  {'City': 'Birjand',
#   'Country': 'IR',
#   'Lat': 32.87,
#   'Lng': 59.22,
#   'Max Temp': 75.2,
#   'Humidity': 19,
#   'Cloudiness': 40,
#   'Wind Speed': 13.87},
#  {'City': 'Casablanca',
#   'Country': 'MA',
#   'Lat': 33.59,
#   'Lng': -7.62,
#   'Max Temp': 84.2,
#   'Humidity': 65,
#   'Cloudiness': 45,
#   'Wind Speed': 9.17},
#  {'City': 'Tavricheskoye',
#   'Country': 'RU',
#   'Lat': 54.59,
#   'Lng': 73.64,
#   'Max Temp': 28.4,
#   'Humidity': 68,
#   'Cloudiness': 40,
#   'Wind Speed': 8.95},
#  {'City': 'Coquimbo',
#   'Country': 'CL',
#   'Lat': -29.95,
#   'Lng': -71.34,
#   'Max Temp': 57.2,
#   'Humidity': 76,
#   'Cloudiness': 5,
#   'Wind Speed': 9.17},
#  {'City': 'Dikson',
#   'Country': 'RU',
#   'Lat': 73.51,
#   'Lng': 80.55,
#   'Max Temp': 33.26,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 18.61},
#  {'City': 'Verkhnyaya Inta',
#   'Country': 'RU',
#   'Lat': 65.98,
#   'Lng': 60.31,
#   'Max Temp': 35.71,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 13.98},
#  {'City': 'Inhambane',
#   'Country': 'MZ',
#   'Lat': -23.86,
#   'Lng': 35.38,
#   'Max Temp': 78.8,
#   'Humidity': 47,
#   'Cloudiness': 20,
#   'Wind Speed': 9.17},
#  {'City': 'Tyret Pervaya',
#   'Country': 'RU',
#   'Lat': 53.67,
#   'Lng': 102.31,
#   'Max Temp': 32.7,
#   'Humidity': 95,
#   'Cloudiness': 95,
#   'Wind Speed': 4.32},
#  {'City': 'Carmen',
#   'Country': 'MX',
#   'Lat': 18.63,
#   'Lng': -91.83,
#   'Max Temp': 77,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 14.63},
#  {'City': 'Vila',
#   'Country': 'PT',
#   'Lat': 42.03,
#   'Lng': -8.16,
#   'Max Temp': 73,
#   'Humidity': 67,
#   'Cloudiness': 18,
#   'Wind Speed': 8.99},
#  {'City': 'Tiksi',
#   'Country': 'RU',
#   'Lat': 71.69,
#   'Lng': 128.87,
#   'Max Temp': 14.95,
#   'Humidity': 93,
#   'Cloudiness': 17,
#   'Wind Speed': 12.44},
#  {'City': 'Yenagoa',
#   'Country': 'NG',
#   'Lat': 4.92,
#   'Lng': 6.26,
#   'Max Temp': 78.8,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 7.36},
#  {'City': 'San Antonio',
#   'Country': 'US',
#   'Lat': 29.42,
#   'Lng': -98.49,
#   'Max Temp': 77,
#   'Humidity': 60,
#   'Cloudiness': 1,
#   'Wind Speed': 3.36},
#  {'City': 'Sibut',
#   'Country': 'CF',
#   'Lat': 5.72,
#   'Lng': 19.07,
#   'Max Temp': 71.92,
#   'Humidity': 89,
#   'Cloudiness': 99,
#   'Wind Speed': 5.88},
#  {'City': 'Jumla',
#   'Country': 'NP',
#   'Lat': 29.27,
#   'Lng': 82.18,
#   'Max Temp': 55.09,
#   'Humidity': 64,
#   'Cloudiness': 48,
#   'Wind Speed': 3.06},
#  {'City': 'Kodiak',
#   'Country': 'US',
#   'Lat': 57.79,
#   'Lng': -152.41,
#   'Max Temp': 48.2,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 25.28},
#  {'City': 'Callaway',
#   'Country': 'US',
#   'Lat': 30.15,
#   'Lng': -85.57,
#   'Max Temp': 84.99,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93},
#  {'City': 'Kiama',
#   'Country': 'AU',
#   'Lat': -34.68,
#   'Lng': 150.87,
#   'Max Temp': 57.99,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 6.78},
#  {'City': 'Sobolevo',
#   'Country': 'RU',
#   'Lat': 54.43,
#   'Lng': 31.9,
#   'Max Temp': 56.88,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 6.51},
#  {'City': 'Thanh Hoa',
#   'Country': 'VN',
#   'Lat': 19.8,
#   'Lng': 105.77,
#   'Max Temp': 75.52,
#   'Humidity': 85,
#   'Cloudiness': 99,
#   'Wind Speed': 10.04},
#  {'City': 'Hobyo',
#   'Country': 'SO',
#   'Lat': 5.35,
#   'Lng': 48.53,
#   'Max Temp': 80.46,
#   'Humidity': 80,
#   'Cloudiness': 16,
#   'Wind Speed': 19.15},
#  {'City': 'Lat Yao',
#   'Country': 'TH',
#   'Lat': 15.75,
#   'Lng': 99.79,
#   'Max Temp': 73.8,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 6.24},
#  {'City': 'Cherskiy',
#   'Country': 'RU',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': 27.37,
#   'Humidity': 99,
#   'Cloudiness': 90,
#   'Wind Speed': 5.44},
#  {'City': 'Makakilo City',
#   'Country': 'US',
#   'Lat': 21.35,
#   'Lng': -158.09,
#   'Max Temp': 77,
#   'Humidity': 78,
#   'Cloudiness': 1,
#   'Wind Speed': 6.26},
#  {'City': 'Torbay',
#   'Country': 'CA',
#   'Lat': 47.67,
#   'Lng': -52.73,
#   'Max Temp': 57.99,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05},
#  {'City': 'Ono',
#   'Country': 'JP',
#   'Lat': 34.85,
#   'Lng': 134.93,
#   'Max Temp': 60.01,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 3},
#  {'City': 'Road Town',
#   'Country': 'VG',
#   'Lat': 18.42,
#   'Lng': -64.62,
#   'Max Temp': 86,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 6.58},
#  {'City': 'Atar',
#   'Country': 'MR',
#   'Lat': 20.52,
#   'Lng': -13.05,
#   'Max Temp': 103.32,
#   'Humidity': 16,
#   'Cloudiness': 0,
#   'Wind Speed': 17.31},
#  {'City': 'Acworth',
#   'Country': 'US',
#   'Lat': 34.07,
#   'Lng': -84.68,
#   'Max Temp': 66.2,
#   'Humidity': 82,
#   'Cloudiness': 1,
#   'Wind Speed': 4.7},
#  {'City': 'Solnechnyy',
#   'Country': 'RU',
#   'Lat': 50.72,
#   'Lng': 136.63,
#   'Max Temp': 38.75,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 2.59},
#  {'City': 'Emporia',
#   'Country': 'US',
#   'Lat': 38.4,
#   'Lng': -96.18,
#   'Max Temp': 62.6,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 5.82},
#  {'City': 'Cidreira',
#   'Country': 'BR',
#   'Lat': -30.18,
#   'Lng': -50.21,
#   'Max Temp': 65.39,
#   'Humidity': 66,
#   'Cloudiness': 81,
#   'Wind Speed': 8.01},
#  {'City': 'Fayetteville',
#   'Country': 'US',
#   'Lat': 35.05,
#   'Lng': -78.88,
#   'Max Temp': 78.01,
#   'Humidity': 53,
#   'Cloudiness': 1,
#   'Wind Speed': 6.93},
#  {'City': 'Ancud',
#   'Country': 'CL',
#   'Lat': -41.87,
#   'Lng': -73.82,
#   'Max Temp': 50,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7},
#  {'City': 'Narsaq',
#   'Country': 'GL',
#   'Lat': 60.92,
#   'Lng': -46.05,
#   'Max Temp': 37.4,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 5.17},
#  {'City': 'Berlevag',
#   'Country': 'NO',
#   'Lat': 70.86,
#   'Lng': 29.09,
#   'Max Temp': 53.6,
#   'Humidity': 71,
#   'Cloudiness': 40,
#   'Wind Speed': 20.8},
#  {'City': 'Ilulissat',
#   'Country': 'GL',
#   'Lat': 69.22,
#   'Lng': -51.1,
#   'Max Temp': 33.8,
#   'Humidity': 40,
#   'Cloudiness': 5,
#   'Wind Speed': 10.29},
#  {'City': 'Ahipara',
#   'Country': 'NZ',
#   'Lat': -35.17,
#   'Lng': 173.17,
#   'Max Temp': 55.98,
#   'Humidity': 87,
#   'Cloudiness': 86,
#   'Wind Speed': 7.43},
#  {'City': 'Sept-Iles',
#   'Country': 'CA',
#   'Lat': 50.2,
#   'Lng': -66.38,
#   'Max Temp': 44.6,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 19.46},
#  {'City': 'Vihti',
#   'Country': 'FI',
#   'Lat': 60.42,
#   'Lng': 24.32,
#   'Max Temp': 57,
#   'Humidity': 87,
#   'Cloudiness': 51,
#   'Wind Speed': 5.99},
#  {'City': 'Morehead',
#   'Country': 'US',
#   'Lat': 37.27,
#   'Lng': -87.18,
#   'Max Temp': 71.6,
#   'Humidity': 88,
#   'Cloudiness': 1,
#   'Wind Speed': 3},
#  {'City': 'Soure',
#   'Country': 'BR',
#   'Lat': -0.72,
#   'Lng': -48.52,
#   'Max Temp': 85.48,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 13.13},
#  {'City': 'Kamenka',
#   'Country': 'RU',
#   'Lat': 51.32,
#   'Lng': 42.77,
#   'Max Temp': 62.01,
#   'Humidity': 26,
#   'Cloudiness': 9,
#   'Wind Speed': 10.92},
#  {'City': 'Manyana',
#   'Country': 'BW',
#   'Lat': -23.4,
#   'Lng': 21.72,
#   'Max Temp': 79.95,
#   'Humidity': 35,
#   'Cloudiness': 16,
#   'Wind Speed': 2.98},
#  {'City': 'Nebug',
#   'Country': 'RU',
#   'Lat': 44.17,
#   'Lng': 39,
#   'Max Temp': 69.48,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 5.28},
#  {'City': 'Joensuu',
#   'Country': 'FI',
#   'Lat': 62.6,
#   'Lng': 29.76,
#   'Max Temp': 55.99,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 10.29},
#  {'City': 'Panjab',
#   'Country': 'AF',
#   'Lat': 34.39,
#   'Lng': 67.02,
#   'Max Temp': 39.54,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 4.25},
#  {'City': 'Boyolangu',
#   'Country': 'ID',
#   'Lat': -8.12,
#   'Lng': 111.89,
#   'Max Temp': 75.72,
#   'Humidity': 83,
#   'Cloudiness': 92,
#   'Wind Speed': 6.87},
#  {'City': 'Atmakur',
#   'Country': 'IN',
#   'Lat': 15.88,
#   'Lng': 78.58,
#   'Max Temp': 77.59,
#   'Humidity': 79,
#   'Cloudiness': 7,
#   'Wind Speed': 1.14},
#  {'City': 'Cuamba',
#   'Country': 'MZ',
#   'Lat': -14.8,
#   'Lng': 36.54,
#   'Max Temp': 86.25,
#   'Humidity': 36,
#   'Cloudiness': 100,
#   'Wind Speed': 3.15},
#  {'City': 'Inongo',
#   'Country': 'CD',
#   'Lat': -1.95,
#   'Lng': 18.27,
#   'Max Temp': 81.21,
#   'Humidity': 68,
#   'Cloudiness': 55,
#   'Wind Speed': 0.81},
#  {'City': 'Uzhur',
#   'Country': 'RU',
#   'Lat': 55.3,
#   'Lng': 89.83,
#   'Max Temp': 27.54,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 5.32},
#  {'City': 'Kondinskoye',
#   'Country': 'RU',
#   'Lat': 59.65,
#   'Lng': 67.41,
#   'Max Temp': 33.33,
#   'Humidity': 88,
#   'Cloudiness': 60,
#   'Wind Speed': 9.53},
#  {'City': 'Nokaneng',
#   'Country': 'BW',
#   'Lat': -19.67,
#   'Lng': 22.27,
#   'Max Temp': 97.92,
#   'Humidity': 10,
#   'Cloudiness': 0,
#   'Wind Speed': 10.98},
#  {'City': 'Lazarev',
#   'Country': 'RU',
#   'Lat': 52.23,
#   'Lng': 141.51,
#   'Max Temp': 46.99,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 6.51},
#  {'City': 'Biak',
#   'Country': 'ID',
#   'Lat': -0.91,
#   'Lng': 122.88,
#   'Max Temp': 77.72,
#   'Humidity': 83,
#   'Cloudiness': 72,
#   'Wind Speed': 0.22},
#  {'City': 'Lima',
#   'Country': 'PE',
#   'Lat': -12.04,
#   'Lng': -77.03,
#   'Max Temp': 63,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 9.17},
#  {'City': 'Georgetown',
#   'Country': 'MY',
#   'Lat': 5.41,
#   'Lng': 100.34,
#   'Max Temp': 80.6,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 3.36},
#  {'City': 'Karangasem',
#   'Country': 'ID',
#   'Lat': -8.45,
#   'Lng': 115.62,
#   'Max Temp': 78.8,
#   'Humidity': 100,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05},
#  {'City': 'Sungaipenuh',
#   'Country': 'ID',
#   'Lat': -2.08,
#   'Lng': 101.38,
#   'Max Temp': 64.47,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.48},
#  {'City': 'Norman Wells',
#   'Country': 'CA',
#   'Lat': 65.28,
#   'Lng': -126.83,
#   'Max Temp': 33.8,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 2.24},
#  {'City': 'Tulsipur',
#   'Country': 'NP',
#   'Lat': 28.13,
#   'Lng': 82.3,
#   'Max Temp': 71.64,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 2.59},
#  {'City': 'Aykhal',
#   'Country': 'RU',
#   'Lat': 66,
#   'Lng': 111.5,
#   'Max Temp': 24.8,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 4.47},
#  {'City': 'Panjakent',
#   'Country': 'TJ',
#   'Lat': 39.5,
#   'Lng': 67.61,
#   'Max Temp': 57.2,
#   'Humidity': 24,
#   'Cloudiness': 40,
#   'Wind Speed': 11.41},
#  {'City': 'Yulara',
#   'Country': 'AU',
#   'Lat': -25.24,
#   'Lng': 130.99,
#   'Max Temp': 62.6,
#   'Humidity': 28,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82},
#  {'City': 'Krasnovishersk',
#   'Country': 'RU',
#   'Lat': 60.41,
#   'Lng': 57.08,
#   'Max Temp': 39.07,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 8.23},
#  {'City': 'Acari',
#   'Country': 'PE',
#   'Lat': -15.43,
#   'Lng': -74.62,
#   'Max Temp': 75.33,
#   'Humidity': 41,
#   'Cloudiness': 64,
#   'Wind Speed': 8.41},
#  {'City': 'Longyearbyen',
#   'Country': 'SJ',
#   'Lat': 78.22,
#   'Lng': 15.64,
#   'Max Temp': 37.4,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 13.87},
#  {'City': 'Novonukutskiy',
#   'Country': 'RU',
#   'Lat': 53.7,
#   'Lng': 102.71,
#   'Max Temp': 33.37,
#   'Humidity': 93,
#   'Cloudiness': 91,
#   'Wind Speed': 3},
#  {'City': 'Katsuura',
#   'Country': 'JP',
#   'Lat': 35.13,
#   'Lng': 140.3,
#   'Max Temp': 62.6,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 9.17},
#  {'City': 'Aurillac',
#   'Country': 'FR',
#   'Lat': 44.92,
#   'Lng': 2.45,
#   'Max Temp': 62.6,
#   'Humidity': 67,
#   'Cloudiness': 74,
#   'Wind Speed': 3.36},
#  {'City': 'Egvekinot',
#   'Country': 'RU',
#   'Lat': 66.32,
#   'Lng': -179.17,
#   'Max Temp': 34.93,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 17.87},
#  {'City': 'Chara',
#   'Country': 'RU',
#   'Lat': 56.91,
#   'Lng': 118.26,
#   'Max Temp': 34.09,
#   'Humidity': 85,
#   'Cloudiness': 69,
#   'Wind Speed': 1.79},
#  {'City': 'Litovko',
#   'Country': 'RU',
#   'Lat': 49.24,
#   'Lng': 135.17,
#   'Max Temp': 39.56,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 7.56},
#  {'City': 'Sergiyevsk',
#   'Country': 'RU',
#   'Lat': 53.94,
#   'Lng': 51.16,
#   'Max Temp': 49.44,
#   'Humidity': 65,
#   'Cloudiness': 88,
#   'Wind Speed': 8.93},
#  {'City': 'Lyndon',
#   'Country': 'US',
#   'Lat': 38.26,
#   'Lng': -85.6,
#   'Max Temp': 69.01,
#   'Humidity': 55,
#   'Cloudiness': 1,
#   'Wind Speed': 5.77},
#  {'City': 'Asfi',
#   'Country': 'MA',
#   'Lat': 32.3,
#   'Lng': -9.24,
#   'Max Temp': 74.12,
#   'Humidity': 59,
#   'Cloudiness': 77,
#   'Wind Speed': 13.15},
#  {'City': 'Ayan',
#   'Country': 'RU',
#   'Lat': 56.45,
#   'Lng': 138.17,
#   'Max Temp': 46.35,
#   'Humidity': 64,
#   'Cloudiness': 75,
#   'Wind Speed': 7.11},
#  {'City': 'Teya',
#   'Country': 'RU',
#   'Lat': 60.38,
#   'Lng': 92.63,
#   'Max Temp': 25.81,
#   'Humidity': 94,
#   'Cloudiness': 66,
#   'Wind Speed': 4.85},
#  {'City': 'Contamana',
#   'Country': 'PE',
#   'Lat': -7.33,
#   'Lng': -75.02,
#   'Max Temp': 96.58,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 1.34},
#  {'City': 'Brae',
#   'Country': 'GB',
#   'Lat': 60.4,
#   'Lng': -1.35,
#   'Max Temp': 51.8,
#   'Humidity': 71,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11},
#  {'City': 'Alice Springs',
#   'Country': 'AU',
#   'Lat': -23.7,
#   'Lng': 133.88,
#   'Max Temp': 59,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82},
#  {'City': 'Severnyy',
#   'Country': 'RU',
#   'Lat': 50.68,
#   'Lng': 36.55,
#   'Max Temp': 66.2,
#   'Humidity': 22,
#   'Cloudiness': 95,
#   'Wind Speed': 13.42},
#  {'City': 'Sinnamary',
#   'Country': 'GF',
#   'Lat': 5.38,
#   'Lng': -52.95,
#   'Max Temp': 87.64,
#   'Humidity': 60,
#   'Cloudiness': 14,
#   'Wind Speed': 9.33},
#  {'City': 'Tamale',
#   'Country': 'GH',
#   'Lat': 9.4,
#   'Lng': -0.84,
#   'Max Temp': 89.51,
#   'Humidity': 52,
#   'Cloudiness': 37,
#   'Wind Speed': 4.65},
#  {'City': 'Bubaque',
#   'Country': 'GW',
#   'Lat': 11.28,
#   'Lng': -15.83,
#   'Max Temp': 82.81,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 8.97},
#  {'City': 'Kutum',
#   'Country': 'SD',
#   'Lat': 14.2,
#   'Lng': 24.67,
#   'Max Temp': 89.67,
#   'Humidity': 15,
#   'Cloudiness': 35,
#   'Wind Speed': 9.84},
#  {'City': 'Luganville',
#   'Country': 'VU',
#   'Lat': -15.53,
#   'Lng': 167.17,
#   'Max Temp': 75.96,
#   'Humidity': 83,
#   'Cloudiness': 98,
#   'Wind Speed': 7.99},
#  {'City': 'Kalayaan',
#   'Country': 'PH',
#   'Lat': 14.35,
#   'Lng': 121.57,
#   'Max Temp': 80.6,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 2.24},
#  {'City': 'Codrington',
#   'Country': 'AU',
#   'Lat': -38.27,
#   'Lng': 141.97,
#   'Max Temp': 51.22,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 21.45},
#  {'City': 'Autun',
#   'Country': 'FR',
#   'Lat': 46.95,
#   'Lng': 4.3,
#   'Max Temp': 68,
#   'Humidity': 59,
#   'Cloudiness': 90,
#   'Wind Speed': 9.17},
#  {'City': 'Lerwick',
#   'Country': 'GB',
#   'Lat': 60.15,
#   'Lng': -1.15,
#   'Max Temp': 51.8,
#   'Humidity': 71,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11},
#  {'City': 'Isangel',
#   'Country': 'VU',
#   'Lat': -19.55,
#   'Lng': 169.27,
#   'Max Temp': 70.9,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 5.95},
#  {'City': 'Pisco',
#   'Country': 'PE',
#   'Lat': -13.7,
#   'Lng': -76.22,
#   'Max Temp': 66,
#   'Humidity': 77,
#   'Cloudiness': 35,
#   'Wind Speed': 4.7},
#  {'City': 'Bathsheba',
#   'Country': 'BB',
#   'Lat': 13.22,
#   'Lng': -59.52,
#   'Max Temp': 87.8,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 14.99},
#  {'City': 'Omsukchan',
#   'Country': 'RU',
#   'Lat': 62.53,
#   'Lng': 155.8,
#   'Max Temp': 22.71,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 2.13},
#  {'City': 'Arinos',
#   'Country': 'BR',
#   'Lat': -15.92,
#   'Lng': -46.11,
#   'Max Temp': 113.34,
#   'Humidity': 10,
#   'Cloudiness': 37,
#   'Wind Speed': 2.64},
#  {'City': 'Kargasok',
#   'Country': 'RU',
#   'Lat': 59.06,
#   'Lng': 80.86,
#   'Max Temp': 32.31,
#   'Humidity': 98,
#   'Cloudiness': 98,
#   'Wind Speed': 10.78},
#  {'City': 'Tommot',
#   'Country': 'RU',
#   'Lat': 58.96,
#   'Lng': 126.29,
#   'Max Temp': 33.44,
#   'Humidity': 92,
#   'Cloudiness': 92,
#   'Wind Speed': 2.08},
#  {'City': 'Dillon',
#   'Country': 'US',
#   'Lat': 34.42,
#   'Lng': -79.37,
#   'Max Temp': 79,
#   'Humidity': 68,
#   'Cloudiness': 1,
#   'Wind Speed': 7.23},
#  {'City': 'Royan',
#   'Country': 'FR',
#   'Lat': 45.63,
#   'Lng': -1.03,
#   'Max Temp': 66.2,
#   'Humidity': 63,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93},
#  {'City': 'Scarborough',
#   'Country': 'GB',
#   'Lat': 54.28,
#   'Lng': -0.4,
#   'Max Temp': 55,
#   'Humidity': 69,
#   'Cloudiness': 73,
#   'Wind Speed': 9.28},
#  {'City': 'Gigmoto',
#   'Country': 'PH',
#   'Lat': 13.78,
#   'Lng': 124.39,
#   'Max Temp': 77.43,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 3.02},
#  {'City': 'Severo-Kurilsk',
#   'Country': 'RU',
#   'Lat': 50.68,
#   'Lng': 156.12,
#   'Max Temp': 46.06,
#   'Humidity': 80,
#   'Cloudiness': 55,
#   'Wind Speed': 16.93},
#  {'City': 'Viedma',
#   'Country': 'AR',
#   'Lat': -40.81,
#   'Lng': -63,
#   'Max Temp': 64,
#   'Humidity': 32,
#   'Cloudiness': 4,
#   'Wind Speed': 3},
#  {'City': 'Aleksandrov Gay',
#   'Country': 'RU',
#   'Lat': 50.15,
#   'Lng': 48.57,
#   'Max Temp': 58.64,
#   'Humidity': 35,
#   'Cloudiness': 16,
#   'Wind Speed': 7.56},
#  {'City': 'Klaksvik',
#   'Country': 'FO',
#   'Lat': 62.23,
#   'Lng': -6.59,
#   'Max Temp': 48.2,
#   'Humidity': 70,
#   'Cloudiness': 11,
#   'Wind Speed': 10.29},
#  {'City': 'Fortuna',
#   'Country': 'US',
#   'Lat': 40.6,
#   'Lng': -124.16,
#   'Max Temp': 53.01,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93},
#  {'City': 'Rosetown',
#   'Country': 'CA',
#   'Lat': 51.55,
#   'Lng': -108,
#   'Max Temp': 48,
#   'Humidity': 53,
#   'Cloudiness': 43,
#   'Wind Speed': 7},
#  {'City': 'Horsham',
#   'Country': 'GB',
#   'Lat': 51.06,
#   'Lng': -0.33,
#   'Max Temp': 63,
#   'Humidity': 77,
#   'Cloudiness': 20,
#   'Wind Speed': 16.11},
#  {'City': 'Tura',
#   'Country': 'IN',
#   'Lat': 25.52,
#   'Lng': 90.22,
#   'Max Temp': 75.25,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 1.81},
#  {'City': 'Arman',
#   'Country': 'RU',
#   'Lat': 59.7,
#   'Lng': 150.17,
#   'Max Temp': 36.97,
#   'Humidity': 75,
#   'Cloudiness': 48,
#   'Wind Speed': 2.75},
#  {'City': 'Broken Hill',
#   'Country': 'AU',
#   'Lat': -31.95,
#   'Lng': 141.43,
#   'Max Temp': 48.2,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05},
#  {'City': 'Laives',
#   'Country': 'IT',
#   'Lat': 46.42,
#   'Lng': 11.33,
#   'Max Temp': 68,
#   'Humidity': 42,
#   'Cloudiness': 21,
#   'Wind Speed': 2.24},
#  {'City': 'Kruisfontein',
#   'Country': 'ZA',
#   'Lat': -34,
#   'Lng': 24.73,
#   'Max Temp': 66.99,
#   'Humidity': 79,
#   'Cloudiness': 69,
#   'Wind Speed': 7},
#  {'City': 'Comodoro Rivadavia',
#   'Country': 'AR',
#   'Lat': -45.87,
#   'Lng': -67.5,
#   'Max Temp': 59,
#   'Humidity': 47,
#   'Cloudiness': 40,
#   'Wind Speed': 10.29},
#  {'City': 'Ciudad Ojeda',
#   'Country': 'VE',
#   'Lat': 10.2,
#   'Lng': -71.31,
#   'Max Temp': 83.61,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 6.93},
#  {'City': 'Limbang',
#   'Country': 'MY',
#   'Lat': 4.75,
#   'Lng': 115,
#   'Max Temp': 82.4,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 2.24},
#  {'City': 'Matagami',
#   'Country': 'CA',
#   'Lat': 49.75,
#   'Lng': -77.63,
#   'Max Temp': 33.8,
#   'Humidity': 80,
#   'Cloudiness': 75,
#   'Wind Speed': 9.17},
#  {'City': 'Baiao',
#   'Country': 'BR',
#   'Lat': -2.79,
#   'Lng': -49.67,
#   'Max Temp': 96.91,
#   'Humidity': 37,
#   'Cloudiness': 2,
#   'Wind Speed': 4.88},
#  {'City': 'Suntar',
#   'Country': 'RU',
#   'Lat': 62.14,
#   'Lng': 117.63,
#   'Max Temp': 28.99,
#   'Humidity': 91,
# ...
#   'Cloudiness': 35,
#   'Wind Speed': 12.97},
#  {'City': 'Visnes',
#   'Country': 'NO',
#   'Lat': 59.36,
#   'Lng': 5.22,
#   'Max Temp': 52,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41},
#  {'City': 'Ossora',
#   'Country': 'RU',
#   'Lat': 59.24,
#   'Lng': 163.07,
#   'Max Temp': 34.11,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 19.22},
#  {'City': 'Augustow',
#   'Country': 'PL',
#   'Lat': 53.84,
#   'Lng': 22.98,
#   'Max Temp': 57.33,
#   'Humidity': 72,
#   'Cloudiness': 70,
#   'Wind Speed': 4.56},
#  {'City': 'Palmer',
#   'Country': 'US',
#   'Lat': 42.16,
#   'Lng': -72.33,
#   'Max Temp': 55.99,
#   'Humidity': 46,
#   'Cloudiness': 1,
#   'Wind Speed': 11.41},
#  {'City': 'Vila Velha',
#   'Country': 'BR',
#   'Lat': -20.33,
#   'Lng': -40.29,
#   'Max Temp': 84.2,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 10.29},
#  {'City': 'Mana',
#   'Country': 'GF',
#   'Lat': 5.66,
#   'Lng': -53.78,
#   'Max Temp': 88,
#   'Humidity': 60,
#   'Cloudiness': 8,
#   'Wind Speed': 8.99},
#  {'City': 'Kaohsiung',
#   'Country': 'TW',
#   'Lat': 22.62,
#   'Lng': 120.31,
#   'Max Temp': 81,
#   'Humidity': 65,
#   'Cloudiness': 90,
#   'Wind Speed': 5.82},
#  {'City': 'Mataram',
#   'Country': 'ID',
#   'Lat': -8.58,
#   'Lng': 116.12,
#   'Max Temp': 78.8,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93},
#  {'City': 'Bontang',
#   'Country': 'ID',
#   'Lat': 0.13,
#   'Lng': 117.5,
#   'Max Temp': 80.47,
#   'Humidity': 82,
#   'Cloudiness': 47,
#   'Wind Speed': 4.5},
#  {'City': 'Bilibino',
#   'Country': 'RU',
#   'Lat': 68.05,
#   'Lng': 166.44,
#   'Max Temp': 21.31,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 2.33},
#  {'City': 'Dauriya',
#   'Country': 'RU',
#   'Lat': 49.93,
#   'Lng': 116.87,
#   'Max Temp': 43.3,
#   'Humidity': 60,
#   'Cloudiness': 100,
#   'Wind Speed': 21.5},
#  {'City': 'Emba',
#   'Country': 'KZ',
#   'Lat': 48.83,
#   'Lng': 58.14,
#   'Max Temp': 42.19,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 9.48},
#  {'City': 'Altoona',
#   'Country': 'US',
#   'Lat': 40.52,
#   'Lng': -78.39,
#   'Max Temp': 55,
#   'Humidity': 71,
#   'Cloudiness': 27,
#   'Wind Speed': 11.74},
#  {'City': 'Invermere',
#   'Country': 'CA',
#   'Lat': 50.52,
#   'Lng': -116.04,
#   'Max Temp': 54.23,
#   'Humidity': 70,
#   'Cloudiness': 72,
#   'Wind Speed': 3.36},
#  {'City': 'Ola',
#   'Country': 'RU',
#   'Lat': 59.58,
#   'Lng': 151.28,
#   'Max Temp': 38.48,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 4.38},
#  {'City': 'Aban',
#   'Country': 'RU',
#   'Lat': 56.67,
#   'Lng': 96.06,
#   'Max Temp': 26.96,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 3.31},
#  {'City': 'Iqaluit',
#   'Country': 'CA',
#   'Lat': 63.75,
#   'Lng': -68.51,
#   'Max Temp': 30.2,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29},
#  {'City': 'Dingle',
#   'Country': 'PH',
#   'Lat': 11,
#   'Lng': 122.67,
#   'Max Temp': 76.24,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01},
#  {'City': 'Ginir',
#   'Country': 'ET',
#   'Lat': 7.13,
#   'Lng': 40.7,
#   'Max Temp': 63.97,
#   'Humidity': 66,
#   'Cloudiness': 73,
#   'Wind Speed': 0.29},
#  {'City': 'Chapais',
#   'Country': 'CA',
#   'Lat': 49.78,
#   'Lng': -74.85,
#   'Max Temp': 33.8,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 13.87},
#  {'City': 'Yinchuan',
#   'Country': 'CN',
#   'Lat': 38.47,
#   'Lng': 106.27,
#   'Max Temp': 58.19,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 5.5},
#  {'City': 'Rio Gallegos',
#   'Country': 'AR',
#   'Lat': -51.62,
#   'Lng': -69.22,
#   'Max Temp': 50,
#   'Humidity': 53,
#   'Cloudiness': 75,
#   'Wind Speed': 28.86},
#  {'City': 'Fairbanks',
#   'Country': 'US',
#   'Lat': 64.84,
#   'Lng': -147.72,
#   'Max Temp': 37.99,
#   'Humidity': 80,
#   'Cloudiness': 40,
#   'Wind Speed': 9.17},
#  {'City': 'Kapit',
#   'Country': 'MY',
#   'Lat': 2.02,
#   'Lng': 112.93,
#   'Max Temp': 76.14,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 0.49},
#  {'City': 'Hobbs',
#   'Country': 'US',
#   'Lat': 32.7,
#   'Lng': -103.14,
#   'Max Temp': 66.99,
#   'Humidity': 62,
#   'Cloudiness': 5,
#   'Wind Speed': 3.36},
#  {'City': 'Charters Towers',
#   'Country': 'AU',
#   'Lat': -20.1,
#   'Lng': 146.27,
#   'Max Temp': 65.26,
#   'Humidity': 79,
#   'Cloudiness': 67,
#   'Wind Speed': 8.03},
#  {'City': 'Vitim',
#   'Country': 'RU',
#   'Lat': 59.45,
#   'Lng': 112.56,
#   'Max Temp': 31.93,
#   'Humidity': 88,
#   'Cloudiness': 80,
#   'Wind Speed': 3.04},
#  {'City': 'Itarema',
#   'Country': 'BR',
#   'Lat': -2.92,
#   'Lng': -39.92,
#   'Max Temp': 87.94,
#   'Humidity': 51,
#   'Cloudiness': 76,
#   'Wind Speed': 17.22},
#  {'City': 'Khani',
#   'Country': 'GE',
#   'Lat': 41.96,
#   'Lng': 42.96,
#   'Max Temp': 75.2,
#   'Humidity': 31,
#   'Cloudiness': 0,
#   'Wind Speed': 29.97},
#  {'City': 'Ambur',
#   'Country': 'IN',
#   'Lat': 12.78,
#   'Lng': 78.7,
#   'Max Temp': 77.65,
#   'Humidity': 64,
#   'Cloudiness': 4,
#   'Wind Speed': 2.39},
#  {'City': 'Sena Madureira',
#   'Country': 'BR',
#   'Lat': -9.07,
#   'Lng': -68.66,
#   'Max Temp': 97.16,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 2.82},
#  {'City': 'Caxito',
#   'Country': 'AO',
#   'Lat': -8.58,
#   'Lng': 13.66,
#   'Max Temp': 82.4,
#   'Humidity': 61,
#   'Cloudiness': 40,
#   'Wind Speed': 9.17},
#  {'City': 'Morondava',
#   'Country': 'MG',
#   'Lat': -20.28,
#   'Lng': 44.28,
#   'Max Temp': 75.42,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 14.34},
#  {'City': 'The Valley',
#   'Country': 'AI',
#   'Lat': 18.22,
#   'Lng': -63.06,
#   'Max Temp': 87.8,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 6.93},
#  {'City': 'Augusto Correa',
#   'Country': 'BR',
#   'Lat': -1.02,
#   'Lng': -46.63,
#   'Max Temp': 88.75,
#   'Humidity': 52,
#   'Cloudiness': 83,
#   'Wind Speed': 8.99},
#  {'City': 'Mahenge',
#   'Country': 'TZ',
#   'Lat': -8.68,
#   'Lng': 36.72,
#   'Max Temp': 80.91,
#   'Humidity': 46,
#   'Cloudiness': 1,
#   'Wind Speed': 5.23},
#  {'City': 'Merauke',
#   'Country': 'ID',
#   'Lat': -8.47,
#   'Lng': 140.33,
#   'Max Temp': 76.05,
#   'Humidity': 84,
#   'Cloudiness': 21,
#   'Wind Speed': 15.05},
#  {'City': 'Ronne',
#   'Country': 'DK',
#   'Lat': 55.1,
#   'Lng': 14.71,
#   'Max Temp': 57.2,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 19.46},
#  {'City': 'Barstow',
#   'Country': 'US',
#   'Lat': 34.9,
#   'Lng': -117.02,
#   'Max Temp': 64.4,
#   'Humidity': 45,
#   'Cloudiness': 1,
#   'Wind Speed': 14.99},
#  {'City': 'Tongchuan',
#   'Country': 'CN',
#   'Lat': 35.08,
#   'Lng': 109.09,
#   'Max Temp': 54.41,
#   'Humidity': 75,
#   'Cloudiness': 62,
#   'Wind Speed': 3.29},
#  {'City': 'San Andres',
#   'Country': 'CO',
#   'Lat': 12.58,
#   'Lng': -81.7,
#   'Max Temp': 86,
#   'Humidity': 79,
#   'Cloudiness': 20,
#   'Wind Speed': 4.7},
#  {'City': 'Zhezkazgan',
#   'Country': 'KZ',
#   'Lat': 47.8,
#   'Lng': 67.71,
#   'Max Temp': 39.52,
#   'Humidity': 64,
#   'Cloudiness': 52,
#   'Wind Speed': 13.96},
#  {'City': 'Pozoblanco',
#   'Country': 'ES',
#   'Lat': 38.38,
#   'Lng': -4.85,
#   'Max Temp': 89.6,
#   'Humidity': 21,
#   'Cloudiness': 98,
#   'Wind Speed': 3.36},
#  {'City': 'Tezu',
#   'Country': 'IN',
#   'Lat': 27.92,
#   'Lng': 96.17,
#   'Max Temp': 75.94,
#   'Humidity': 81,
#   'Cloudiness': 2,
#   'Wind Speed': 3.31},
#  {'City': 'Puerto Quijarro',
#   'Country': 'BO',
#   'Lat': -17.78,
#   'Lng': -57.77,
#   'Max Temp': 108.01,
#   'Humidity': 17,
#   'Cloudiness': 1,
#   'Wind Speed': 7.94},
#  {'City': 'Zhuhai',
#   'Country': 'CN',
#   'Lat': 22.28,
#   'Lng': 113.57,
#   'Max Temp': 77,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 17.22},
#  {'City': 'Pimentel',
#   'Country': 'PE',
#   'Lat': -6.84,
#   'Lng': -79.93,
#   'Max Temp': 66.2,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29},
#  {'City': 'Fare',
#   'Country': 'PF',
#   'Lat': -16.7,
#   'Lng': -151.02,
#   'Max Temp': 78.17,
#   'Humidity': 80,
#   'Cloudiness': 6,
#   'Wind Speed': 19.75},
#  {'City': 'Pitelino',
#   'Country': 'RU',
#   'Lat': 54.58,
#   'Lng': 41.81,
#   'Max Temp': 53.78,
#   'Humidity': 42,
#   'Cloudiness': 64,
#   'Wind Speed': 9.24},
#  {'City': 'Lishui',
#   'Country': 'CN',
#   'Lat': 28.46,
#   'Lng': 119.91,
#   'Max Temp': 59.2,
#   'Humidity': 85,
#   'Cloudiness': 2,
#   'Wind Speed': 2.28},
#  {'City': 'Sao Joao Da Barra',
#   'Country': 'BR',
#   'Lat': -21.64,
#   'Lng': -41.05,
#   'Max Temp': 84.2,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 17.22},
#  {'City': 'Krasnoturansk',
#   'Country': 'RU',
#   'Lat': 54.32,
#   'Lng': 91.56,
#   'Max Temp': 33.8,
#   'Humidity': 80,
#   'Cloudiness': 40,
#   'Wind Speed': 8.95},
#  {'City': 'Nuevitas',
#   'Country': 'CU',
#   'Lat': 21.55,
#   'Lng': -77.26,
#   'Max Temp': 82.4,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 10.29},
#  {'City': 'Fort Morgan',
#   'Country': 'US',
#   'Lat': 40.25,
#   'Lng': -103.8,
#   'Max Temp': 50,
#   'Humidity': 34,
#   'Cloudiness': 1,
#   'Wind Speed': 3.36},
#  {'City': 'Salinopolis',
#   'Country': 'BR',
#   'Lat': -0.61,
#   'Lng': -47.36,
#   'Max Temp': 84.79,
#   'Humidity': 65,
#   'Cloudiness': 99,
#   'Wind Speed': 12.75},
#  {'City': 'Sebrovo',
#   'Country': 'RU',
#   'Lat': 50.1,
#   'Lng': 43.3,
#   'Max Temp': 55.81,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 10.65},
#  {'City': 'Atchison',
#   'Country': 'US',
#   'Lat': 39.56,
#   'Lng': -95.12,
#   'Max Temp': 66,
#   'Humidity': 72,
#   'Cloudiness': 8,
#   'Wind Speed': 9.28},
#  {'City': 'Togur',
#   'Country': 'RU',
#   'Lat': 58.36,
#   'Lng': 82.83,
#   'Max Temp': 22.78,
#   'Humidity': 97,
#   'Cloudiness': 82,
#   'Wind Speed': 5.61},
#  {'City': 'Ulaangom',
#   'Country': 'MN',
#   'Lat': 49.98,
#   'Lng': 92.07,
#   'Max Temp': 37.94,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44},
#  {'City': 'Leshukonskoye',
#   'Country': 'RU',
#   'Lat': 64.9,
#   'Lng': 45.76,
#   'Max Temp': 47.05,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 4.05},
#  {'City': 'Pergamino',
#   'Country': 'AR',
#   'Lat': -33.89,
#   'Lng': -60.57,
#   'Max Temp': 73.99,
#   'Humidity': 27,
#   'Cloudiness': 0,
#   'Wind Speed': 5.59},
#  {'City': 'Juneau',
#   'Country': 'US',
#   'Lat': 58.3,
#   'Lng': -134.42,
#   'Max Temp': 44.6,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 10.29},
#  {'City': 'Ternate',
#   'Country': 'ID',
#   'Lat': 0.8,
#   'Lng': 127.4,
#   'Max Temp': 81.16,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 2.57},
#  {'City': 'Atambua',
#   'Country': 'ID',
#   'Lat': -9.11,
#   'Lng': 124.89,
#   'Max Temp': 75.9,
#   'Humidity': 84,
#   'Cloudiness': 91,
#   'Wind Speed': 2.3},
#  {'City': 'Olafsvik',
#   'Country': 'IS',
#   'Lat': 64.89,
#   'Lng': -23.71,
#   'Max Temp': 44.31,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 12.01},
#  {'City': 'Oktyabrskoye',
#   'Country': 'RU',
#   'Lat': 43.06,
#   'Lng': 44.74,
#   'Max Temp': 59,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 8.95},
#  {'City': 'Nampula',
#   'Country': 'MZ',
#   'Lat': -15.12,
#   'Lng': 39.27,
#   'Max Temp': 84.2,
#   'Humidity': 42,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93},
#  {'City': 'Churapcha',
#   'Country': 'RU',
#   'Lat': 62,
#   'Lng': 132.43,
#   'Max Temp': 28.13,
#   'Humidity': 93,
#   'Cloudiness': 9,
#   'Wind Speed': 5.73},
#  {'City': 'Tacoronte',
#   'Country': 'ES',
#   'Lat': 28.48,
#   'Lng': -16.41,
#   'Max Temp': 79,
#   'Humidity': 54,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05},
#  {'City': 'High Level',
#   'Country': 'CA',
#   'Lat': 58.52,
#   'Lng': -117.14,
#   'Max Temp': 41,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 2.24},
#  {'City': 'Whangamata',
#   'Country': 'NZ',
#   'Lat': -37.2,
#   'Lng': 175.87,
#   'Max Temp': 53.01,
#   'Humidity': 68,
#   'Cloudiness': 95,
#   'Wind Speed': 8.01},
#  {'City': 'Nuuk',
#   'Country': 'GL',
#   'Lat': 64.18,
#   'Lng': -51.72,
#   'Max Temp': 35.6,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93},
#  {'City': 'Alexandria',
#   'Country': 'EG',
#   'Lat': 31.22,
#   'Lng': 29.96,
#   'Max Temp': 87.8,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 11.41},
#  {'City': 'Awjilah',
#   'Country': 'LY',
#   'Lat': 29.11,
#   'Lng': 21.29,
#   'Max Temp': 94.89,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 19.3},
#  {'City': 'Petropavlovsk-Kamchatskiy',
#   'Country': 'RU',
#   'Lat': 53.05,
#   'Lng': 158.65,
#   'Max Temp': 33.8,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 4.47},
#  {'City': 'Pangoa',
#   'Country': 'PE',
#   'Lat': -12.12,
#   'Lng': -73,
#   'Max Temp': 92.03,
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind Speed': 1.79},
#  {'City': 'Anloga',
#   'Country': 'GH',
#   'Lat': 5.79,
#   'Lng': 0.9,
#   'Max Temp': 86,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 12.75},
#  {'City': 'Szekesfehervar',
#   'Country': 'HU',
#   'Lat': 47.19,
#   'Lng': 18.41,
#   'Max Temp': 64,
#   'Humidity': 49,
#   'Cloudiness': 18,
#   'Wind Speed': 3},
#  {'City': 'High Rock',
#   'Country': 'BS',
#   'Lat': 26.62,
#   'Lng': -78.28,
#   'Max Temp': 84.2,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93},
#  {'City': 'Kalmunai',
#   'Country': 'LK',
#   'Lat': 7.42,
#   'Lng': 81.82,
#   'Max Temp': 82.65,
#   'Humidity': 78,
#   'Cloudiness': 87,
#   'Wind Speed': 8.34},
#  {'City': 'Aragats',
#   'Country': 'AM',
#   'Lat': 40.49,
#   'Lng': 44.35,
#   'Max Temp': 64.4,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 1.12},
#  {'City': 'Okato',
#   'Country': 'NZ',
#   'Lat': -39.2,
#   'Lng': 173.88,
#   'Max Temp': 46.99,
#   'Humidity': 78,
#   'Cloudiness': 99,
#   'Wind Speed': 5.99},
#  {'City': 'Puerto Escondido',
#   'Country': 'MX',
#   'Lat': 15.85,
#   'Lng': -97.07,
#   'Max Temp': 75.2,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 9.17},
#  {'City': 'Tadine',
#   'Country': 'NC',
#   'Lat': -21.55,
#   'Lng': 167.88,
#   'Max Temp': 70.79,
#   'Humidity': 89,
#   'Cloudiness': 1,
#   'Wind Speed': 10.4},
#  {'City': 'Saint-Joseph',
#   'Country': 'RE',
#   'Lat': -21.37,
#   'Lng': 55.62,
#   'Max Temp': 77,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 2.24},
#  {'City': 'Westport',
#   'Country': 'US',
#   'Lat': 41.14,
#   'Lng': -73.36,
#   'Max Temp': 61,
#   'Humidity': 44,
#   'Cloudiness': 1,
#   'Wind Speed': 13.87},
#  {'City': 'Sagua La Grande',
#   'Country': 'CU',
#   'Lat': 22.81,
#   'Lng': -80.08,
#   'Max Temp': 80.6,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 9.17},
#  {'City': 'Hofn',
#   'Country': 'IS',
#   'Lat': 64.25,
#   'Lng': -15.21,
#   'Max Temp': 46.4,
#   'Humidity': 81,
#   'Cloudiness': 20,
#   'Wind Speed': 6.93},
#  {'City': 'Manggar',
#   'Country': 'ID',
#   'Lat': -2.88,
#   'Lng': 108.27,
#   'Max Temp': 80.56,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 6.17},
#  {'City': 'Algiers',
#   'Country': 'DZ',
#   'Lat': 36.75,
#   'Lng': 3.04,
#   'Max Temp': 78.8,
#   'Humidity': 61,
#   'Cloudiness': 20,
#   'Wind Speed': 18.34},
#  {'City': 'Tosno',
#   'Country': 'RU',
#   'Lat': 59.54,
#   'Lng': 30.88,
#   'Max Temp': 57.2,
#   'Humidity': 82,
#   'Cloudiness': 90,
#   'Wind Speed': 4.47},
#  {'City': 'Aranos',
#   'Country': 'NA',
#   'Lat': -24.13,
#   'Lng': 19.12,
#   'Max Temp': 88.45,
#   'Humidity': 18,
#   'Cloudiness': 0,
#   'Wind Speed': 7.58},
#  {'City': 'Smoky Lake',
#   'Country': 'CA',
#   'Lat': 54.12,
#   'Lng': -112.47,
#   'Max Temp': 42.01,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 4.45},
#  {'City': 'Maniitsoq',
#   'Country': 'GL',
#   'Lat': 65.42,
#   'Lng': -52.9,
#   'Max Temp': 38.14,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 18.84},
#  {'City': 'Akita',
#   'Country': 'JP',
#   'Lat': 39.72,
#   'Lng': 140.12,
#   'Max Temp': 55.98,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 5.44},
#  {'City': 'Gambela',
#   'Country': 'ET',
#   'Lat': 8.25,
#   'Lng': 34.58,
#   'Max Temp': 80.64,
#   'Humidity': 77,
#   'Cloudiness': 33,
#   'Wind Speed': 4.43},
#  {'City': 'Agirish',
#   'Country': 'RU',
#   'Lat': 61.92,
#   'Lng': 63.02,
#   'Max Temp': 35.46,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 8.59},
#  {'City': 'Kubachi',
#   'Country': 'RU',
#   'Lat': 42.09,
#   'Lng': 47.6,
#   'Max Temp': 42.01,
#   'Humidity': 87,
#   'Cloudiness': 1,
#   'Wind Speed': 4},
#  {'City': 'Alugan',
#   'Country': 'PH',
#   'Lat': 12.22,
#   'Lng': 125.48,
#   'Max Temp': 77.41,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 3.24},
#  {'City': 'Dali',
#   'Country': 'CN',
#   'Lat': 25.7,
#   'Lng': 100.18,
#   'Max Temp': 61.97,
#   'Humidity': 86,
#   'Cloudiness': 55,
#   'Wind Speed': 3.85},
#  {'City': 'Portree',
#   'Country': 'GB',
#   'Lat': 57.41,
#   'Lng': -6.19,
#   'Max Temp': 48.99,
#   'Humidity': 79,
#   'Cloudiness': 9,
#   'Wind Speed': 1.99},
#  {'City': 'Harwich',
#   'Country': 'GB',
#   'Lat': 51.94,
#   'Lng': 1.28,
#   'Max Temp': 59,
#   'Humidity': 74,
#   'Cloudiness': 99,
#   'Wind Speed': 8.99},
#  {'City': 'Laureles',
#   'Country': 'US',
#   'Lat': 26.11,
#   'Lng': -97.49,
#   'Max Temp': 82,
#   'Humidity': 86,
#   'Cloudiness': 99,
#   'Wind Speed': 4}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#         City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0    Kokstad      ZA -30.55   29.42     74.77        44          41
# 1     Gilgit      PK  35.92   74.31     70.75        23          65
# 2  Busselton      AU -33.65  115.33     52.00        68          78
# 3     Bethel      US  41.37  -73.41     57.99        50           1
# 4        Bud      US  39.45  -86.18     66.00        53           0
#
#    Wind Speed
# 0       11.34
# 1        6.62
# 2        5.03
# 3       12.75
# 4        5.68

# %%
# Create the output file
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
#Dataframe with 731 cities
